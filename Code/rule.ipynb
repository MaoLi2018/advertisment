# %%
import time
import pandas as pd
import numpy as np
import lightgbm as lgb
import config
from sklearn.metrics import log_loss

# %%
###组合信息
timeFeatList = [
    ['user_id','day'],
    ['user_id','day','hour'],
    ['item_id','day'],
    ['item_id','day','hour'],
    ['shop_id','day'],
    ['shop_id','day','hour'],
    ['item_brand_id','day'],
    ['item_brand_id','day','hour'],
    ['item_city_id','day'],
    ['item_city_id','day','hour'],
]

# %%
def timestamp_datetime(value):
    return time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(value))

def time_feat(df,featList,featName):
    tmp = df.groupby(featList).size().reset_index().rename(columns={0:featName})
    df = df.merge(tmp,'left',on=featList)
    return df

def process(df):
    df['time'] = df.context_timestamp.apply(timestamp_datetime)
    df['day'] = df.time.apply(lambda x: int(x[8:10]))
    df['hour'] = df.time.apply(lambda x: int(x[11:13]))
    for lst in timeFeatList:
        df = time_feat(df,lst,'_'.join(lst))
    df['item_property_list'] = dfTrain['item_property_list'].apply(lambda x:';'.join(sorted(set(str(x).split(';')))))
    df["missing_feat"] = np.sum((df == -1).values, axis=1)
    return df

# %%
dfTrain = pd.read_table(config.TRAIN_FILE,sep=' ')
dfTrain.drop_duplicates(inplace=True)
dfTest = pd.read_table(config.TEST_FILE,sep=' ')

dfTrain = process(dfTrain)
dfTest = process(dfTest)

# %%
train_idx = dfTrain.loc[dfTrain['day']<24].index
valid_idx = dfTrain.loc[dfTrain['day']==24].index

featList = ['item_id','item_brand_id','item_city_id','item_price_level','item_sales_level','item_collected_level','item_pv_level',
            'user_gender_id','user_age_level','user_occupation_id','user_star_level',
            'context_page_id','item_property_list',
            'shop_id','shop_review_num_level',
            'is_trade'
]

Xi_train_ = dfTrain.loc[train_idx,featList]
Xi_valid_ = dfTrain.loc[valid_idx,featList]

# %%
naFill = Xi_train_['is_trade'].mean()
for var in featList[:-1]:
    Xi_valid_ =Xi_valid_.merge(Xi_train_.groupby(var)['is_trade'].mean().reset_index().rename(columns={'is_trade':'is_trade_'+var}),'left',on=var).fillna(naFill-0.002)

# %%
for var in featList[:-1]:
    print(var)
    print(log_loss(Xi_valid_['is_trade'], Xi_valid_['is_trade_'+var]))
# Out:
# item_id
# 0.164508097503
# item_brand_id
# 0.106458787713
# item_city_id
# 0.0871674952809
# item_price_level
# 0.08448929218
# item_sales_level
# 0.0848416444282
# item_collected_level
# 0.085556296131
# item_pv_level
# 0.085604273448
# user_gender_id
# 0.0856237040705
# user_age_level
# 0.0856016794557
# user_occupation_id
# 0.0856860338078
# user_star_level
# 0.0856776825034
# context_page_id
# 0.0856012697589
# item_property_list
# 0.180038916187
# shop_id
# 0.122164200327
# shop_review_num_level
# 0.0855232943286

# %%
for i in range(len(featList[:-1])-2):
    for j in range(i+1,len(featList[:-1])-1):
        for k in range(j+1,len(featList[:-1])):
            print(featList[i],featList[j],featList[k])
            print(log_loss(Xi_valid_['is_trade'], Xi_valid_[['is_trade_'+featList[i],'is_trade_'+featList[j],'is_trade_'+featList[k]]].mean(axis=1)))
# Out:
# item_id item_brand_id item_city_id
# 0.0845891605086
# item_id item_brand_id item_price_level
# 0.0834249547992
# item_id item_brand_id item_sales_level
# 0.0834272891554
# item_id item_brand_id item_collected_level
# 0.0834861195031
# item_id item_brand_id item_pv_level
# 0.0834968990507
# item_id item_brand_id user_gender_id
# 0.0834961278624
# item_id item_brand_id user_age_level
# 0.0834407271629
# item_id item_brand_id user_occupation_id
# 0.0834790304698
# item_id item_brand_id user_star_level
# 0.0834683456873
# item_id item_brand_id context_page_id
# 0.0834746373808
# item_id item_brand_id item_property_list
# 0.0867137411025
# item_id item_brand_id shop_id
# 0.1028285011
# item_id item_brand_id shop_review_num_level
# 0.083517435933
# item_id item_city_id item_price_level
# 0.0834011290394
# item_id item_city_id item_sales_level
# 0.0834790723842
# item_id item_city_id item_collected_level
# 0.0836258995569
# item_id item_city_id item_pv_level
# 0.0836595505651
# item_id item_city_id user_gender_id
# 0.0836515779154
# item_id item_city_id user_age_level
# 0.0836093401684
# item_id item_city_id user_occupation_id
# 0.0836520865266
# item_id item_city_id user_star_level
# 0.0836383939924
# item_id item_city_id context_page_id
# 0.0836404091115
# item_id item_city_id item_property_list
# 0.0840094162789
# item_id item_city_id shop_id
# 0.0856868066412
# item_id item_city_id shop_review_num_level
# 0.0836261621031
# item_id item_price_level item_sales_level
# 0.0832063829228
# item_id item_price_level item_collected_level
# 0.0833848613639
# item_id item_price_level item_pv_level
# 0.0834170964708
# item_id item_price_level user_gender_id
# 0.0834302063762
# item_id item_price_level user_age_level
# 0.0833764776269
# item_id item_price_level user_occupation_id
# 0.0834278704865
# item_id item_price_level user_star_level
# 0.0834198226351
# item_id item_price_level context_page_id
# 0.0834107136295
# item_id item_price_level item_property_list
# 0.0838288738024
# item_id item_price_level shop_id
# 0.083486054752
# item_id item_price_level shop_review_num_level
# 0.0834082024365
# item_id item_sales_level item_collected_level
# 0.0835425707074
# item_id item_sales_level item_pv_level
# 0.0835427334938
# item_id item_sales_level user_gender_id
# 0.0835279741739
# item_id item_sales_level user_age_level
# 0.0834922226661
# item_id item_sales_level user_occupation_id
# 0.0835254512403
# item_id item_sales_level user_star_level
# 0.083512113663
# item_id item_sales_level context_page_id
# 0.0835169324768
# item_id item_sales_level item_property_list
# 0.0837960193931
# item_id item_sales_level shop_id
# 0.083558401379
# item_id item_sales_level shop_review_num_level
# 0.0835015183003
# item_id item_collected_level item_pv_level
# 0.0837195491158
# item_id item_collected_level user_gender_id
# 0.0837175813557
# item_id item_collected_level user_age_level
# 0.0836784417499
# item_id item_collected_level user_occupation_id
# 0.08371713645
# item_id item_collected_level user_star_level
# 0.0837052573134
# item_id item_collected_level context_page_id
# 0.0837020795354
# item_id item_collected_level item_property_list
# 0.0839320850256
# item_id item_collected_level shop_id
# 0.08354653526
# item_id item_collected_level shop_review_num_level
# 0.0836892043969
# item_id item_pv_level user_gender_id
# 0.0837453598239
# item_id item_pv_level user_age_level
# 0.0837074484319
# item_id item_pv_level user_occupation_id
# 0.0837446188515
# item_id item_pv_level user_star_level
# 0.0837333806955
# item_id item_pv_level context_page_id
# 0.0837286116134
# item_id item_pv_level item_property_list
# 0.0839794004915
# item_id item_pv_level shop_id
# 0.0835638360539
# item_id item_pv_level shop_review_num_level
# 0.0837140926226
# item_id user_gender_id user_age_level
# 0.0837186176878
# item_id user_gender_id user_occupation_id
# 0.0837520100475
# item_id user_gender_id user_star_level
# 0.0837424962884
# item_id user_gender_id context_page_id
# 0.0837343746619
# item_id user_gender_id item_property_list
# 0.0839747889882
# item_id user_gender_id shop_id
# 0.0835420831587
# item_id user_gender_id shop_review_num_level
# 0.0837184379389
# item_id user_age_level user_occupation_id
# 0.0837140849762
# item_id user_age_level user_star_level
# 0.0837019951796
# item_id user_age_level context_page_id
# 0.0836973098358
# item_id user_age_level item_property_list
# 0.0839324467706
# item_id user_age_level shop_id
# 0.0834859616398
# item_id user_age_level shop_review_num_level
# 0.0836770777046
# item_id user_occupation_id user_star_level
# 0.0837416342277
# item_id user_occupation_id context_page_id
# 0.0837348173379
# item_id user_occupation_id item_property_list
# 0.0839659067677
# item_id user_occupation_id shop_id
# 0.0835111287225
# item_id user_occupation_id shop_review_num_level
# 0.0837181107013
# item_id user_star_level context_page_id
# 0.0837224995374
# item_id user_star_level item_property_list
# 0.083962862437
# item_id user_star_level shop_id
# 0.0835080907321
# item_id user_star_level shop_review_num_level
# 0.0837078169504
# item_id context_page_id item_property_list
# 0.083951996952
# item_id context_page_id shop_id
# 0.0835079600607
# item_id context_page_id shop_review_num_level
# 0.083702131435
# item_id item_property_list shop_id
# 0.0918861321463
# item_id item_property_list shop_review_num_level
# 0.0839763123634
# item_id shop_id shop_review_num_level
# 0.0835630154624
# item_brand_id item_city_id item_price_level
# 0.0837127135172
# item_brand_id item_city_id item_sales_level
# 0.0837709516142
# item_brand_id item_city_id item_collected_level
# 0.0839877335955
# item_brand_id item_city_id item_pv_level
# 0.0840141700762
# item_brand_id item_city_id user_gender_id
# 0.084022268299
# item_brand_id item_city_id user_age_level
# 0.083974801871
# item_brand_id item_city_id user_occupation_id
# 0.0840336762546
# item_brand_id item_city_id user_star_level
# 0.0840153532481
# item_brand_id item_city_id context_page_id
# 0.0840120119508
# item_brand_id item_city_id item_property_list
# 0.0842768206002
# item_brand_id item_city_id shop_id
# 0.0845332861126
# item_brand_id item_city_id shop_review_num_level
# 0.0839975723713
# item_brand_id item_price_level item_sales_level
# 0.0834947367584
# item_brand_id item_price_level item_collected_level
# 0.0837360278858
# item_brand_id item_price_level item_pv_level
# 0.0837661642235
# item_brand_id item_price_level user_gender_id
# 0.0837867445283
# item_brand_id item_price_level user_age_level
# 0.0837262996983
# item_brand_id item_price_level user_occupation_id
# 0.0837953988181
# item_brand_id item_price_level user_star_level
# 0.0837797013696
# item_brand_id item_price_level context_page_id
# 0.0837692394405
# item_brand_id item_price_level item_property_list
# 0.0840937689615
# item_brand_id item_price_level shop_id
# 0.0833671771746
# item_brand_id item_price_level shop_review_num_level
# 0.0837686798985
# item_brand_id item_sales_level item_collected_level
# 0.0838911603802
# item_brand_id item_sales_level item_pv_level
# 0.0838928184557
# item_brand_id item_sales_level user_gender_id
# 0.0838880825393
# item_brand_id item_sales_level user_age_level
# 0.0838464263979
# item_brand_id item_sales_level user_occupation_id
# 0.0838969017433
# item_brand_id item_sales_level user_star_level
# 0.0838789037095
# item_brand_id item_sales_level context_page_id
# 0.0838772025675
# item_brand_id item_sales_level item_property_list
# 0.0840612066755
# item_brand_id item_sales_level shop_id
# 0.0833281415882
# item_brand_id item_sales_level shop_review_num_level
# 0.0838619754274
# item_brand_id item_collected_level item_pv_level
# 0.0841343362699
# item_brand_id item_collected_level user_gender_id
# 0.0841410015636
# item_brand_id item_collected_level user_age_level
# 0.0840969322343
# item_brand_id item_collected_level user_occupation_id
# 0.0841510297537
# item_brand_id item_collected_level user_star_level
# 0.0841336664803
# item_brand_id item_collected_level context_page_id
# 0.084127591908
# item_brand_id item_collected_level item_property_list
# 0.0842697806823
# item_brand_id item_collected_level shop_id
# 0.0834254919118
# item_brand_id item_collected_level shop_review_num_level
# 0.0841127891727
# item_brand_id item_pv_level user_gender_id
# 0.084165478394
# item_brand_id item_pv_level user_age_level
# 0.0841222287797
# item_brand_id item_pv_level user_occupation_id
# 0.0841753043536
# item_brand_id item_pv_level user_star_level
# 0.0841583899492
# item_brand_id item_pv_level context_page_id
# 0.0841504359184
# item_brand_id item_pv_level item_property_list
# 0.0843115795341
# item_brand_id item_pv_level shop_id
# 0.0834444362132
# item_brand_id item_pv_level shop_review_num_level
# 0.0841355765316
# item_brand_id user_gender_id user_age_level
# 0.0841404854238
# item_brand_id user_gender_id user_occupation_id
# 0.084190196964
# item_brand_id user_gender_id user_star_level
# 0.0841741156326
# item_brand_id user_gender_id context_page_id
# 0.084164042163
# item_brand_id user_gender_id item_property_list
# 0.0843140600294
# item_brand_id user_gender_id shop_id
# 0.0834509124063
# item_brand_id user_gender_id shop_review_num_level
# 0.0841480856093
# item_brand_id user_age_level user_occupation_id
# 0.0841474578561
# item_brand_id user_age_level user_star_level
# 0.0841292309138
# item_brand_id user_age_level context_page_id
# 0.0841211616084
# item_brand_id user_age_level item_property_list
# 0.0842677549627
# item_brand_id user_age_level shop_id
# 0.0833959177813
# item_brand_id user_age_level shop_review_num_level
# 0.0841011659368
# item_brand_id user_occupation_id user_star_level
# 0.0841841396218
# item_brand_id user_occupation_id context_page_id
# 0.0841747105382
# item_brand_id user_occupation_id item_property_list
# 0.0843220613117
# item_brand_id user_occupation_id shop_id
# 0.0834380099281
# item_brand_id user_occupation_id shop_review_num_level
# 0.0841579890293
# item_brand_id user_star_level context_page_id
# 0.0841568774041
# item_brand_id user_star_level item_property_list
# 0.0843057574955
# item_brand_id user_star_level shop_id
# 0.0834265387768
# item_brand_id user_star_level shop_review_num_level
# 0.0841414472846
# item_brand_id context_page_id item_property_list
# 0.0842931734656
# item_brand_id context_page_id shop_id
# 0.0834240540844
# item_brand_id context_page_id shop_review_num_level
# 0.0841337809438
# item_brand_id item_property_list shop_id
# 0.0866903982159
# item_brand_id item_property_list shop_review_num_level
# 0.0843186480379
# item_brand_id shop_id shop_review_num_level
# 0.0834754067315
# item_city_id item_price_level item_sales_level
# 0.0842435480225
# item_city_id item_price_level item_collected_level
# 0.0845492095044
# item_city_id item_price_level item_pv_level
# 0.0845784483493
# item_city_id item_price_level user_gender_id
# 0.0845984085917
# item_city_id item_price_level user_age_level
# 0.0845452487759
# item_city_id item_price_level user_occupation_id
# 0.0846185683128
# item_city_id item_price_level user_star_level
# 0.0846040403297
# item_city_id item_price_level context_page_id
# 0.0845893446184
# item_city_id item_price_level item_property_list
# 0.0845999479715
# item_city_id item_price_level shop_id
# 0.0833835642102
# item_city_id item_price_level shop_review_num_level
# 0.0845474162075
# item_city_id item_sales_level item_collected_level
# 0.0848394356049
# item_city_id item_sales_level item_pv_level
# 0.0848490544392
# item_city_id item_sales_level user_gender_id
# 0.0848389395636
# item_city_id item_sales_level user_age_level
# 0.0848033410767
# item_city_id item_sales_level user_occupation_id
# 0.0848603882309
# item_city_id item_sales_level user_star_level
# 0.0848404325448
# item_city_id item_sales_level context_page_id
# 0.0848347051541
# item_city_id item_sales_level item_property_list
# 0.0847462597002
# item_city_id item_sales_level shop_id
# 0.083430084074
# item_city_id item_sales_level shop_review_num_level
# 0.0847803058146
# item_city_id item_collected_level item_pv_level
# 0.0851612032974
# item_city_id item_collected_level user_gender_id
# 0.0851641951074
# item_city_id item_collected_level user_age_level
# 0.0851252722831
# item_city_id item_collected_level user_occupation_id
# 0.0851871932175
# item_city_id item_collected_level user_star_level
# 0.0851679215341
# item_city_id item_collected_level context_page_id
# 0.0851570445087
# item_city_id item_collected_level item_property_list
# 0.085011232435
# item_city_id item_collected_level shop_id
# 0.0836179979664
# item_city_id item_collected_level shop_review_num_level
# 0.085100730905
# item_city_id item_pv_level user_gender_id
# 0.0851912417993
# item_city_id item_pv_level user_age_level
# 0.0851533897081
# item_city_id item_pv_level user_occupation_id
# 0.0852136844426
# item_city_id item_pv_level user_star_level
# 0.08519440153
# item_city_id item_pv_level context_page_id
# 0.0851832032942
# item_city_id item_pv_level item_property_list
# 0.0850533473677
# item_city_id item_pv_level shop_id
# 0.0836560343209
# item_city_id item_pv_level shop_review_num_level
# 0.0851259818618
# item_city_id user_gender_id user_age_level
# 0.0851690519259
# item_city_id user_gender_id user_occupation_id
# 0.0852264703552
# item_city_id user_gender_id user_star_level
# 0.0852077961732
# item_city_id user_gender_id context_page_id
# 0.0851939926759
# item_city_id user_gender_id item_property_list
# 0.0850483980336
# item_city_id user_gender_id shop_id
# 0.0836538847078
# item_city_id user_gender_id shop_review_num_level
# 0.085136213236
# item_city_id user_age_level user_occupation_id
# 0.0851891895523
# item_city_id user_age_level user_star_level
# 0.0851685479906
# item_city_id user_age_level context_page_id
# 0.0851559347422
# item_city_id user_age_level item_property_list
# 0.0850129052981
# item_city_id user_age_level shop_id
# 0.0836067985127
# item_city_id user_age_level shop_review_num_level
# 0.0850948859088
# item_city_id user_occupation_id user_star_level
# 0.0852307939604
# item_city_id user_occupation_id context_page_id
# 0.0852172906819
# item_city_id user_occupation_id item_property_list
# 0.085069856082
# item_city_id user_occupation_id shop_id
# 0.0836569539891
# item_city_id user_occupation_id shop_review_num_level
# 0.0851588483648
# item_city_id user_star_level context_page_id
# 0.0851976421042
# item_city_id user_star_level item_property_list
# 0.0850488668039
# item_city_id user_star_level shop_id
# 0.0836446755003
# item_city_id user_star_level shop_review_num_level
# 0.0851402187361
# item_city_id context_page_id item_property_list
# 0.0850402578717
# item_city_id context_page_id shop_id
# 0.0836381201195
# item_city_id context_page_id shop_review_num_level
# 0.085128640513
# item_city_id item_property_list shop_id
# 0.0840325315111
# item_city_id item_property_list shop_review_num_level
# 0.0850030506305
# item_city_id shop_id shop_review_num_level
# 0.0836326848696
# item_price_level item_sales_level item_collected_level
# 0.0844624235745
# item_price_level item_sales_level item_pv_level
# 0.0844750476741
# item_price_level item_sales_level user_gender_id
# 0.0844785305358
# item_price_level item_sales_level user_age_level
# 0.0844289809429
# item_price_level item_sales_level user_occupation_id
# 0.0844958996701
# item_price_level item_sales_level user_star_level
# 0.0844827262292
# item_price_level item_sales_level context_page_id
# 0.084467525363
# item_price_level item_sales_level item_property_list
# 0.0844205494025
# item_price_level item_sales_level shop_id
# 0.0831467184813
# item_price_level item_sales_level shop_review_num_level
# 0.0844267354568
# item_price_level item_collected_level item_pv_level
# 0.084803485863
# item_price_level item_collected_level user_gender_id
# 0.0848195179396
# item_price_level item_collected_level user_age_level
# 0.0847672652541
# item_price_level item_collected_level user_occupation_id
# 0.0848388064365
# item_price_level item_collected_level user_star_level
# 0.0848267321094
# item_price_level item_collected_level context_page_id
# 0.0848056183601
# item_price_level item_collected_level item_property_list
# 0.0846996942322
# item_price_level item_collected_level shop_id
# 0.0833649345114
# item_price_level item_collected_level shop_review_num_level
# 0.0847640931793
# item_price_level item_pv_level user_gender_id
# 0.084850100642
# item_price_level item_pv_level user_age_level
# 0.084799017476
# item_price_level item_pv_level user_occupation_id
# 0.0848685795459
# item_price_level item_pv_level user_star_level
# 0.0848566044148
# item_price_level item_pv_level context_page_id
# 0.084835040315
# item_price_level item_pv_level item_property_list
# 0.0847461819145
# item_price_level item_pv_level shop_id
# 0.0834026538495
# item_price_level item_pv_level shop_review_num_level
# 0.0847920185374
# item_price_level user_gender_id user_age_level
# 0.0848264176486
# item_price_level user_gender_id user_occupation_id
# 0.0848933691807
# item_price_level user_gender_id user_star_level
# 0.0848822321087
# item_price_level user_gender_id context_page_id
# 0.0848580745626
# item_price_level user_gender_id item_property_list
# 0.084753947276
# item_price_level user_gender_id shop_id
# 0.0834217475228
# item_price_level user_gender_id shop_review_num_level
# 0.0848150010173
# item_price_level user_age_level user_occupation_id
# 0.0848423795095
# item_price_level user_age_level user_star_level
# 0.0848293992124
# item_price_level user_age_level context_page_id
# 0.0848065469814
# item_price_level user_age_level item_property_list
# 0.0846999111446
# item_price_level user_age_level shop_id
# 0.083364185836
# item_price_level user_age_level shop_review_num_level
# 0.0847609217242
# item_price_level user_occupation_id user_star_level
# 0.0849010952474
# item_price_level user_occupation_id context_page_id
# 0.0848775598484
# item_price_level user_occupation_id item_property_list
# 0.0847696618471
# item_price_level user_occupation_id shop_id
# 0.0834225812836
# item_price_level user_occupation_id shop_review_num_level
# 0.0848339924201
# item_price_level user_star_level context_page_id
# 0.0848651897972
# item_price_level user_star_level item_property_list
# 0.084757919614
# item_price_level user_star_level shop_id
# 0.0834145105389
# item_price_level user_star_level shop_review_num_level
# 0.0848221670953
# item_price_level context_page_id item_property_list
# 0.0847369773277
# item_price_level context_page_id shop_id
# 0.0833977228609
# item_price_level context_page_id shop_review_num_level
# 0.0848007869447
# item_price_level item_property_list shop_id
# 0.0838296919018
# item_price_level item_property_list shop_review_num_level
# 0.0847162941219
# item_price_level shop_id shop_review_num_level
# 0.0834031030471
# item_sales_level item_collected_level item_pv_level
# 0.0851967093761
# item_sales_level item_collected_level user_gender_id
# 0.0851833657602
# item_sales_level item_collected_level user_age_level
# 0.0851495729785
# item_sales_level item_collected_level user_occupation_id
# 0.0852035287707
# item_sales_level item_collected_level user_star_level
# 0.0851848690363
# item_sales_level item_collected_level context_page_id
# 0.0851735175851
# item_sales_level item_collected_level item_property_list
# 0.0849793399233
# item_sales_level item_collected_level shop_id
# 0.0834831654467
# item_sales_level item_collected_level shop_review_num_level
# 0.0851186221361
# item_sales_level item_pv_level user_gender_id
# 0.0851904431859
# item_sales_level item_pv_level user_age_level
# 0.0851579823776
# item_sales_level item_pv_level user_occupation_id
# 0.085210255037
# item_sales_level item_pv_level user_star_level
# 0.0851915388263
# item_sales_level item_pv_level context_page_id
# 0.0851795824044
# item_sales_level item_pv_level item_property_list
# 0.0849959276898
# item_sales_level item_pv_level shop_id
# 0.0834947162167
# item_sales_level item_pv_level shop_review_num_level
# 0.0851231790707
# item_sales_level user_gender_id user_age_level
# 0.0851568881002
# item_sales_level user_gender_id user_occupation_id
# 0.0852064321415
# item_sales_level user_gender_id user_star_level
# 0.0851886691129
# item_sales_level user_gender_id context_page_id
# 0.0851744027729
# item_sales_level user_gender_id item_property_list
# 0.0849752841769
# item_sales_level user_gender_id shop_id
# 0.0834858808555
# item_sales_level user_gender_id shop_review_num_level
# 0.0851177841508
# item_sales_level user_age_level user_occupation_id
# 0.0851743978753
# item_sales_level user_age_level user_star_level
# 0.0851549657617
# item_sales_level user_age_level context_page_id
# 0.0851415969701
# item_sales_level user_age_level item_property_list
# 0.0849408067152
# item_sales_level user_age_level shop_id
# 0.0834454038283
# item_sales_level user_age_level shop_review_num_level
# 0.0850819713439
# item_sales_level user_occupation_id user_star_level
# 0.0852088670558
# item_sales_level user_occupation_id context_page_id
# 0.0851951511473
# item_sales_level user_occupation_id item_property_list
# 0.08499384411
# item_sales_level user_occupation_id shop_id
# 0.0834860456641
# item_sales_level user_occupation_id shop_review_num_level
# 0.0851375508578
# item_sales_level user_star_level context_page_id
# 0.0851759613771
# item_sales_level user_star_level item_property_list
# 0.0849743205854
# item_sales_level user_star_level shop_id
# 0.0834749596021
# item_sales_level user_star_level shop_review_num_level
# 0.0851195555248
# item_sales_level context_page_id item_property_list
# 0.0849631144322
# item_sales_level context_page_id shop_id
# 0.0834676071446
# item_sales_level context_page_id shop_review_num_level
# 0.0851077968657
# item_sales_level item_property_list shop_id
# 0.0837943526599
# item_sales_level item_property_list shop_review_num_level
# 0.0849295997424
# item_sales_level shop_id shop_review_num_level
# 0.0834627652975
# item_collected_level item_pv_level user_gender_id
# 0.0855447218034
# item_collected_level item_pv_level user_age_level
# 0.0855096261118
# item_collected_level item_pv_level user_occupation_id
# 0.0855662550744
# item_collected_level item_pv_level user_star_level
# 0.0855480957538
# item_collected_level item_pv_level context_page_id
# 0.0855308199786
# item_collected_level item_pv_level item_property_list
# 0.0852855634984
# item_collected_level item_pv_level shop_id
# 0.083709044401
# item_collected_level item_pv_level shop_review_num_level
# 0.0854721952855
# item_collected_level user_gender_id user_age_level
# 0.085520854279
# item_collected_level user_gender_id user_occupation_id
# 0.08557485005
# item_collected_level user_gender_id user_star_level
# 0.0855575875909
# item_collected_level user_gender_id context_page_id
# 0.0855379791212
# item_collected_level user_gender_id item_property_list
# 0.0852743473304
# item_collected_level user_gender_id shop_id
# 0.0837138575263
# item_collected_level user_gender_id shop_review_num_level
# 0.0854787000546
# item_collected_level user_age_level user_occupation_id
# 0.0855397888889
# item_collected_level user_age_level user_star_level
# 0.0855212408013
# item_collected_level user_age_level context_page_id
# 0.0855024057661
# item_collected_level user_age_level item_property_list
# 0.0852365950352
# item_collected_level user_age_level shop_id
# 0.0836709479192
# item_collected_level user_age_level shop_review_num_level
# 0.0854403185576
# item_collected_level user_occupation_id user_star_level
# 0.0855796039048
# item_collected_level user_occupation_id context_page_id
# 0.0855603818284
# item_collected_level user_occupation_id item_property_list
# 0.0852941843432
# item_collected_level user_occupation_id shop_id
# 0.0837162696015
# item_collected_level user_occupation_id shop_review_num_level
# 0.0855003289832
# item_collected_level user_star_level context_page_id
# 0.0855420423219
# item_collected_level user_star_level item_property_list
# 0.085276584394
# item_collected_level user_star_level shop_id
# 0.0837054294128
# item_collected_level user_star_level shop_review_num_level
# 0.0854830406082
# item_collected_level context_page_id item_property_list
# 0.0852593729569
# item_collected_level context_page_id shop_id
# 0.0836940021698
# item_collected_level context_page_id shop_review_num_level
# 0.0854656928929
# item_collected_level item_property_list shop_id
# 0.0839604264335
# item_collected_level item_property_list shop_review_num_level
# 0.0852253594771
# item_collected_level shop_id shop_review_num_level
# 0.0836887991621
# item_pv_level user_gender_id user_age_level
# 0.085548593891
# item_pv_level user_gender_id user_occupation_id
# 0.0856005935129
# item_pv_level user_gender_id user_star_level
# 0.0855833934813
# item_pv_level user_gender_id context_page_id
# 0.0855632483657
# item_pv_level user_gender_id item_property_list
# 0.0853139908049
# item_pv_level user_gender_id shop_id
# 0.0837487945596
# item_pv_level user_gender_id shop_review_num_level
# 0.0855028963878
# item_pv_level user_age_level user_occupation_id
# 0.0855668888593
# item_pv_level user_age_level user_star_level
# 0.0855483498251
# item_pv_level user_age_level context_page_id
# 0.0855289626418
# item_pv_level user_age_level item_property_list
# 0.0852784743094
# item_pv_level user_age_level shop_id
# 0.0837068014825
# item_pv_level user_age_level shop_review_num_level
# 0.085465794599
# item_pv_level user_occupation_id user_star_level
# 0.0856047987108
# item_pv_level user_occupation_id context_page_id
# 0.0855852374083
# item_pv_level user_occupation_id item_property_list
# 0.085332749751
# item_pv_level user_occupation_id shop_id
# 0.0837499468618
# item_pv_level user_occupation_id shop_review_num_level
# 0.0855242362659
# item_pv_level user_star_level context_page_id
# 0.0855667758182
# item_pv_level user_star_level item_property_list
# 0.0853160989276
# item_pv_level user_star_level shop_id
# 0.083740910785
# item_pv_level user_star_level shop_review_num_level
# 0.0855067943481
# item_pv_level context_page_id item_property_list
# 0.0852969650112
# item_pv_level context_page_id shop_id
# 0.0837268249282
# item_pv_level context_page_id shop_review_num_level
# 0.0854891181192
# item_pv_level item_property_list shop_id
# 0.084022108493
# item_pv_level item_property_list shop_review_num_level
# 0.0852618009487
# item_pv_level shop_id shop_review_num_level
# 0.0837200020556
# user_gender_id user_age_level user_occupation_id
# 0.0855866419064
# user_gender_id user_age_level user_star_level
# 0.0855688109903
# user_gender_id user_age_level context_page_id
# 0.0855470202459
# user_gender_id user_age_level item_property_list
# 0.0852823865841
# user_gender_id user_age_level shop_id
# 0.0837229677362
# user_gender_id user_age_level shop_review_num_level
# 0.0854837348017
# user_gender_id user_occupation_id user_star_level
# 0.0856227897956
# user_gender_id user_occupation_id context_page_id
# 0.0856009045159
# user_gender_id user_occupation_id item_property_list
# 0.0853339745915
# user_gender_id user_occupation_id shop_id
# 0.0837627018169
# user_gender_id user_occupation_id shop_review_num_level
# 0.0855396454561
# user_gender_id user_star_level context_page_id
# 0.0855831849151
# user_gender_id user_star_level item_property_list
# 0.0853187100491
# user_gender_id user_star_level shop_id
# 0.083754059851
# user_gender_id user_star_level shop_review_num_level
# 0.0855229697118
# user_gender_id context_page_id item_property_list
# 0.0852977488153
# user_gender_id context_page_id shop_id
# 0.0837377512276
# user_gender_id context_page_id shop_review_num_level
# 0.085502925047
# user_gender_id item_property_list shop_id
# 0.0840177409726
# user_gender_id item_property_list shop_review_num_level
# 0.0852615725328
# user_gender_id shop_id shop_review_num_level
# 0.083730473638
# user_age_level user_occupation_id user_star_level
# 0.0855874239697
# user_age_level user_occupation_id context_page_id
# 0.0855664821885
# user_age_level user_occupation_id item_property_list
# 0.0852986890133
# user_age_level user_occupation_id shop_id
# 0.0837214262992
# user_age_level user_occupation_id shop_review_num_level
# 0.0855023653891
# user_age_level user_star_level context_page_id
# 0.0855472360481
# user_age_level user_star_level item_property_list
# 0.0852812282595
# user_age_level user_star_level shop_id
# 0.0837103686528
# user_age_level user_star_level shop_review_num_level
# 0.0854841891011
# user_age_level context_page_id item_property_list
# 0.0852613231658
# user_age_level context_page_id shop_id
# 0.0836966526969
# user_age_level context_page_id shop_review_num_level
# 0.0854652477874
# user_age_level item_property_list shop_id
# 0.0839722993079
# user_age_level item_property_list shop_review_num_level
# 0.0852214033668
# user_age_level shop_id shop_review_num_level
# 0.0836853980319
# user_occupation_id user_star_level context_page_id
# 0.085605628171
# user_occupation_id user_star_level item_property_list
# 0.0853369142598
# user_occupation_id user_star_level shop_id
# 0.0837557592352
# user_occupation_id user_star_level shop_review_num_level
# 0.0855447133541
# user_occupation_id context_page_id item_property_list
# 0.085318107348
# user_occupation_id context_page_id shop_id
# 0.0837412971917
# user_occupation_id context_page_id shop_review_num_level
# 0.08552511764
# user_occupation_id item_property_list shop_id
# 0.0840081665295
# user_occupation_id item_property_list shop_review_num_level
# 0.085280773942
# user_occupation_id shop_id shop_review_num_level
# 0.0837333489971
# user_star_level context_page_id item_property_list
# 0.0853005946248
# user_star_level context_page_id shop_id
# 0.083729733733
# user_star_level context_page_id shop_review_num_level
# 0.0855073873736
# user_star_level item_property_list shop_id
# 0.084008927999
# user_star_level item_property_list shop_review_num_level
# 0.085263711715
# user_star_level shop_id shop_review_num_level
# 0.0837230493073
# context_page_id item_property_list shop_id
# 0.0839883065923
# context_page_id item_property_list shop_review_num_level
# 0.0852464731004
# context_page_id shop_id shop_review_num_level
# 0.0837101662748
# item_property_list shop_id shop_review_num_level
# 0.0840189476925
