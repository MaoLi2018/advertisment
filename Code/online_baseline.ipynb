# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.cluster import KMeans
import time

# %%
from sklearn.metrics import roc_curve
def ks_metric(true,score):
    fpr, tpr, thresholds = roc_curve(true,score)
    ks = max(tpr-fpr)
    return ks

# %%
# global data
drop_list = []


def timestamp_datetime(value):
    tm_format = '%Y-%m-%d %H:%M:%S'
    value = time.localtime(value)
    dt = time.strftime(tm_format, value)
    return dt


def extract_time(data):
    data['context_timestamp'] = data['context_timestamp'].apply(timestamp_datetime)
    data['context_timestamp'] = pd.to_datetime(data['context_timestamp'])

    data['day'] = data['context_timestamp'].dt.day
    data['hour'] = data['context_timestamp'].dt.hour
    data['hour'] = data['hour'].apply(map_hour)
    return data.drop('context_timestamp', axis=1)


def map_hour(x):
    if (x >= 7) & (x <= 12):
        return 1
    elif (x >= 13) & (x <= 20):
        return 2
    return 3


def process_on_hour(data):
    data['hour_map'] = data['hour'].apply(map_hour)
    return data.drop('hour', axis=1)


def category_trans(col):
    values = col.unique()
    tran = col.copy()
    for i in range(len(values)):
        tran[col == values[i]] = i
    tran.astype(int)
    return tran


def user_info_process(data):
    data['user_gender_id'] = data['user_gender_id'].map({-1: -1, 0: 0, 1: 1, 2: 0}).astype(int)
    data['user_gender_id'] += 1

    data.loc[data['user_age_level'] < 1002, 'user_age_level'] = 0
    data.loc[data['user_age_level'] > 1003, 'user_age_level'] = 2
    data.loc[data['user_age_level'] > 1000, 'user_age_level'] = 1

    data['user_occupation_id'] = data['user_occupation_id'].map({-1: 0, 2003: 0, 2002: 1, 2004: 1, 2005: 1}).astype(int)

    data.loc[data['user_star_level'] < 3001, 'user_star_level'] = 0
    data.loc[data['user_star_level'] > 3008, 'user_star_level'] = 2
    data.loc[data['user_star_level'] > 2999, 'user_star_level'] = 1

    return data


def get_category_list(data):
    #   data['category_0'] = data['item_category_list'].apply(lambda x: str(x).split(';')[0])
    data['category_1'] = data['item_category_list'].apply(lambda x: str(x).split(';')[1])
    data['category_2'] = data['item_category_list'].apply(
        lambda x: str(x).split(';')[2] if len(str(x).split(';')) > 2 else 'None')
    data = data.drop('item_category_list', axis=1)

    for col in ['category_1', 'category_2']:
        values = data[col].unique()
        data[col] = category_trans(data[col])

    data['category_2'] = data['category_2'] == 0
    data['category_1'].replace([3, 5, 8, 9], 3, inplace=True)
    data['category_1'].replace([7, 10, 11, 12], 7, inplace=True)

    data['category_1'] = category_trans(data['category_1'])
    return data


def get_property_list(data):
    data['property_0'] = data['item_property_list'].apply(lambda x: str(x).split(";")[0])
    data['property_1'] = data['item_property_list'].apply(lambda x: str(x).split(";")[1])
    data['property_2'] = data['item_property_list'].apply(
        lambda x: str(x).split(';')[2] if len(str(x).split(';')) > 2 else 'None')
    data = data.drop('item_property_list', axis=1)

    for col in ['property_'+str(x) for x in range(3)]:
        pass
    return data


def item_info_process(data):
    data = get_category_list(data)
    # data = get_property_list(data)

    return data


def get_brand_info(data):
    # get the features of item brand
    nums_item = data.groupby('item_brand_id', as_index=False)['item_id'].agg(
        {'item_nums_brand': lambda x: len(x.unique())})
    nums_shop = data.groupby('item_brand_id', as_index=False)['shop_id'].agg(
        {'shop_nums_brand': lambda x: len(x.unique())})
    nums_ins = data.groupby('item_brand_id', as_index=False)['instance_id'].agg({'instance_nums_brand': 'count'})
    nums_user = data.groupby('item_brand_id', as_index=False)['user_id'].agg(
        {'user_nums_brand': 'count', 'fans_nums_brand': lambda x: len(x.unique())})
    # nums_trade = data.groupby('item_brand_id', as_index=False)['is_trade'].agg(
    # {'trade_ratio_brand': lambda x: x.sum()})
    avg_collected = data.groupby('item_brand_id', as_index=False)['item_collected_level'].agg(
        {'avg_collected_brand': lambda x: x.sum()/x.shape[0]})

    brand_info = None
    for tmp in [nums_item, nums_shop, nums_ins, nums_user, avg_collected]:
        if brand_info is None:
            brand_info = tmp
        else:
            brand_info = pd.merge(left=brand_info, right=tmp, how='left', on='item_brand_id')

    # brand_info.sort_values('trade_ratio_brand', ascending=False, inplace=True)
    brand_info['item_per_shop'] = brand_info['item_nums_brand'] / brand_info['shop_nums_brand']
    # normalization
    for col in brand_info.columns:
        if col not in['item_brand_id', 'item_per_shop']:
            mean = brand_info[col].mean()
            std = brand_info[col].std()
            brand_info[col] = (brand_info[col] - mean) / std

    brand_info['brand_label'] = KMeans(n_clusters=7, random_state=10).fit_predict(brand_info.drop('item_brand_id', axis=1))
    brand_info = dummy(brand_info, ['brand_label'])

    return brand_info


def get_shop_info(data):
    base_cols = ['shop_review_num_level', 'shop_review_positive_rate', 'shop_star_level', 'shop_score_service',
                 'shop_score_delivery', 'shop_score_description']
    shop_base = data[['shop_id']+base_cols].copy()
    shop_base.drop_duplicates(['shop_id'], inplace=True)

    # get the features of shop
    nums_item = data.groupby('shop_id', as_index=False)['item_id'].agg({'item_nums_shop': lambda x: len(x.unique())})
    nums_brand = data.groupby('shop_id', as_index=False)['item_brand_id'].agg(
        {'brand_nums_shop': lambda x: len(x.unique())})
    nums_ins = data.groupby('shop_id', as_index=False)['instance_id'].agg({'instance_nums_shop': 'count'})
    nums_user = data.groupby('shop_id', as_index=False)['user_id'].agg(
        {'user_nums_shop': 'count', 'fans_nums_shop': lambda x: len(x.unique())})
    shop_info = None
    for tmp in [nums_item, nums_brand, nums_ins, nums_user, shop_base]:
        if shop_info is None:
            shop_info = tmp
        else:
            shop_info = pd.merge(left=shop_info, right=tmp, how='left', on='shop_id')

    shop_info['item_brand'] = shop_info['item_nums_shop'] / shop_info['brand_nums_shop']
    #
    # print shop_info.head(10)

    for col in shop_info.columns:
        if col not in['shop_id', 'item_brand', 'shop_review_positive_rate', 'shop_score_service',
                      'shop_score_delivery', 'shop_score_description']:
            mean = shop_info[col].mean()
            std = shop_info[col].std()
            shop_info[col] = (shop_info[col] - mean) / std

    shop_info['shop_label'] = KMeans(n_clusters=3, random_state=10).fit_predict(shop_info.drop('shop_id', axis=1))
    shop_info = dummy(shop_info, ['shop_label'])

    shop_info.drop(base_cols, axis=1, inplace=True)
    return shop_info


def id_transform(train, test, ids):
    concated = pd.concat([train, test], axis=0)

    for id in ids:
        sumer = concated.groupby(id)[['is_trade']].sum()+1
        counter = concated.groupby(id)[['is_trade']].count()+10
        ratio = sumer / counter
        print(type(ratio))
        ratio = ratio.reset_index()
        print(ratio.describe())
        print(ratio.shape)
        print(ratio.head(5))

        ratio.columns = [id, id+'_ratio']
        concated = pd.merge(left=concated, right=ratio, how='left', on=id)

    concated.drop(ids, axis=1, inplace=True)

    train = concated[:train.shape[0]]
    test = concated[train.shape[0]:]

    return train, test


def dummy(data, columns):
    for column in columns:
        if column not in data.columns:
            continue
        dummy_data = pd.get_dummies(data[column], drop_first=False)
        # rename columns: column name + 1,2,3
        c_num = len(dummy_data.columns)

        dummy_data.columns = [column + str(x + 1) for x in range(c_num)]
        data = pd.concat([data, dummy_data], axis=1)

        data = data.drop(column, axis=1)
    return data


def normalization(data, cols):
    for col in cols:
        mean = data[col].mean()
        std = data[col].std()
        data[col] = (data[col] - mean) / std
    return data


def data_process(data):
    data = extract_time(data)
    data = user_info_process(data)
    data = item_info_process(data)
    #   data = shop_info_process(data)
    data.drop(drop_list, 1, inplace=True)
    return data


def process_on_concat(train, test, process, *args, **keys):
    concated = pd.concat([train.drop('is_trade', 1), test], axis=0)
    concated = process(concated, *args, **keys)

    train_part = concated[:train.shape[0]]
    train = pd.concat([train_part, train['is_trade']], axis=1)

    test = concated[train.shape[0]:]
    return train, test


def log_loss(label, proba):
    loss = 0.0
    loss += np.sum(np.log(proba[label == 1]))
    loss += np.sum(np.log(1 - proba[label == 0]))
    return loss / len(proba)


def cross_valid(train, model, not_used):
    # get the used data
    used_col = [col for col in train.columns if col not in not_used]
    train = train[used_col]
    X, y = train.drop('is_trade', 1), train['is_trade']
    skf = StratifiedKFold(n_splits=5, random_state=7, shuffle=False)
    skf.get_n_splits(X, y)
    epoch = 0
    loss = 0.0
    for train_index, valid_index in skf.split(X, y):
        Xtr, Xva = X.iloc[train_index], X.iloc[valid_index]
        ytr, yva = y.iloc[train_index], y.iloc[valid_index]
        model.fit(Xtr, ytr)
        pred = model.predict_proba(Xva)
        pred = pred[:, -1]
        # print pred.shape, yva.shape
        logloss = log_loss(yva, pred)
        loss += logloss
        print('[%d] log loss - %.4f' % (epoch, logloss))
        epoch += 1

    print('[cross valid] mean of log loss - %.4f' % (loss / 5))


def last_day_valid(data, model, not_used):
    # train valid split
    train = data[data['day'] < 24]
    valid = data[data['day'] == 24]
    # get the used data
    used_col = [col for col in train.columns if col not in not_used]
    train = train[used_col]
    valid = valid[used_col]
    # train and valid
    model.fit(train.drop('is_trade', 1), train['is_trade'])
    pred = model.predict_proba(valid.drop('is_trade', 1))
    pred = pred[:, -1]
    loss = log_loss(valid['is_trade'], pred)
    print('[last day valid] log loss - %.4f' % loss)


def check_df_format(data):
    print(type(data))
    print(data.shape)
    print(data.info())


def submit(train, test, model, not_used):
    ins_id = test['instance_id']
    used_col = [col for col in train.columns if col not in not_used]
    train = train[used_col]
    used_col.remove('is_trade')
    feat = test[used_col]

    date = time.localtime(time.time())
    date = str(date.tm_mon) + '-' + str(date.tm_mday)
    model.fit(train.drop('is_trade', 1), train['is_trade'])

    pred = model.predict_proba(feat)

    test['predicted_score'] = pred[:, 1]
    test['instance_id'] = ins_id.values

    sub = test[['instance_id', 'predicted_score']]

    sub.to_csv('output/submit%s.txt' % date, index=False, sep=" ")


def get_test_trade_by_lr(train, test, not_used):
    used_col = [col for col in train.columns if col not in not_used]
    train = train[used_col]
    used_col.remove('is_trade')
    test = test[used_col]
    model = LogisticRegression()
    model.fit(train.drop('is_trade', 1), train['is_trade'])
    pred = model.predict(test)
    return pred

# %%
no_used = ['instance_id', 'shop_id', 'user_id', 'item_id', 'item_city_id', 'item_brand_id', 'day',
                'item_category_list', 'item_property_list', 'predict_category_property',
                ]
ids = ['shop_id', 'item_id']

train_df = pd.read_table('../../Data/advertisment/Raw/round1_ijcai_18_train_20180301.txt', sep='\s+')
test_df = pd.read_table('../../Data/advertisment/Raw/round1_ijcai_18_test_a_20180301.txt', sep='\s+')
concated = pd.concat([train_df.drop('is_trade', 1), test_df])

# %%
# brand cluster
brand_df = get_brand_info(concated)
shop_df = get_shop_info(concated)

result = test_df['instance_id']

# %%
# feature extraction
train_df = data_process(train_df)
test_df = data_process(test_df)
ohe_list = ['user_gender_id', 'user_age_level', 'user_occupation_id', 'user_star_level']
norm_list = ['item_price_level', 'item_sales_level', 'item_collected_level', 'shop_star_level']

train_df, test_df = process_on_concat(train_df, test_df, dummy, ohe_list)
train_df, test_df = process_on_concat(train_df, test_df, normalization, norm_list)
# merge data
train_df = pd.merge(left=train_df, right=brand_df, how='left', on='item_brand_id')
train_df = pd.merge(left=train_df, right=shop_df, how='left', on='shop_id')

test_df = pd.merge(left=test_df, right=brand_df, how='left', on='item_brand_id')
test_df = pd.merge(left=test_df, right=shop_df, how='left', on='shop_id')
# get the ratio of each id

test_df['is_trade'] = get_test_trade_by_lr(train_df, test_df, no_used)

# train_df, test_df = id_transform(train_df, test_df, ids)
test_df.drop('is_trade', axis=1, inplace=True)

# %%
train_df.columns
# Out:
# Index(['instance_id', 'item_id', 'item_property_list', 'item_brand_id',
#        'item_city_id', 'item_price_level', 'item_sales_level',
#        'item_collected_level', 'item_pv_level', 'user_id', 'context_id',
#        'context_page_id', 'predict_category_property', 'shop_id',
#        'shop_review_num_level', 'shop_review_positive_rate', 'shop_star_level',
#        'shop_score_service', 'shop_score_delivery', 'shop_score_description',
#        'day', 'hour', 'category_1', 'category_2', 'user_gender_id1',
#        'user_gender_id2', 'user_gender_id3', 'user_age_level1',
#        'user_age_level2', 'user_age_level3', 'user_occupation_id1',
#        'user_occupation_id2', 'user_star_level1', 'user_star_level2',
#        'user_star_level3', 'is_trade', 'item_nums_brand', 'shop_nums_brand',
#        'instance_nums_brand', 'user_nums_brand', 'fans_nums_brand',
#        'avg_collected_brand', 'item_per_shop', 'brand_label1', 'brand_label2',
#        'brand_label3', 'brand_label4', 'brand_label5', 'brand_label6',
#        'brand_label7', 'item_nums_shop', 'brand_nums_shop',
#        'instance_nums_shop', 'user_nums_shop', 'fans_nums_shop', 'item_brand',
#        'shop_label1', 'shop_label2', 'shop_label3'],
#       dtype='object')

# %%
train= train_df[(train_df['day'] >= 18) & (train_df['day'] <= 23)]
test= train_df[(train_df['day'] == 24)]

# %%
col = [col for col in train.columns if col not in no_used+['is_trade']]
leaf = 35
X = train[col]
y = train['is_trade'].values
X_tes = test[col]
y_tes = test['is_trade'].values
print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    # metric='binary_error',
    num_leaves=leaf,
    depth=8,
    learning_rate=0.05,
    seed=2018,
    colsample_bytree=0.8,
    # min_child_samples=8,
    subsample=0.9,
    n_estimators=20000)
lgb_model = lgb0.fit(X, y, eval_set=[(X_tes, y_tes)], early_stopping_rounds=200)
best_iter = lgb_model.best_iteration_
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)
print(feat_imp)
print(feat_imp.shape)
# pred= lgb_model.predict(test[col])
pred = lgb_model.predict_proba(test[col])[:, 1]
test['pred'] = pred
test['index'] = range(len(test))
# print(test[['is_trade','pred']])
print('误差 ', log_loss(test['is_trade'], test['pred']))
print('KS ', ks_metric(test['is_trade'], test['pred']))
ks = ks_metric(test['is_trade'], test['pred'])
# Out:
# Training LGBM model...
# [1]	valid_0's binary_logloss: 0.647782
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.606729
# [3]	valid_0's binary_logloss: 0.569405
# [4]	valid_0's binary_logloss: 0.535375
# [5]	valid_0's binary_logloss: 0.504207
# [6]	valid_0's binary_logloss: 0.475601
# [7]	valid_0's binary_logloss: 0.449273
# [8]	valid_0's binary_logloss: 0.424999
# [9]	valid_0's binary_logloss: 0.40253
# [10]	valid_0's binary_logloss: 0.38173
# [11]	valid_0's binary_logloss: 0.362442
# [12]	valid_0's binary_logloss: 0.344536
# [13]	valid_0's binary_logloss: 0.327866
# [14]	valid_0's binary_logloss: 0.312328
# [15]	valid_0's binary_logloss: 0.297856
# [16]	valid_0's binary_logloss: 0.284349
# [17]	valid_0's binary_logloss: 0.271729
# [18]	valid_0's binary_logloss: 0.259945
# [19]	valid_0's binary_logloss: 0.248922
# [20]	valid_0's binary_logloss: 0.238598
# [21]	valid_0's binary_logloss: 0.228932
# [22]	valid_0's binary_logloss: 0.219879
# [23]	valid_0's binary_logloss: 0.211384
# [24]	valid_0's binary_logloss: 0.203425
# [25]	valid_0's binary_logloss: 0.195967
# [26]	valid_0's binary_logloss: 0.188962
# [27]	valid_0's binary_logloss: 0.182384
# [28]	valid_0's binary_logloss: 0.176204
# [29]	valid_0's binary_logloss: 0.170405
# [30]	valid_0's binary_logloss: 0.164962
# [31]	valid_0's binary_logloss: 0.15985
# [32]	valid_0's binary_logloss: 0.155049
# [33]	valid_0's binary_logloss: 0.150533
# [34]	valid_0's binary_logloss: 0.14629
# [35]	valid_0's binary_logloss: 0.142305
# [36]	valid_0's binary_logloss: 0.138569
# [37]	valid_0's binary_logloss: 0.135036
# [38]	valid_0's binary_logloss: 0.131727
# [39]	valid_0's binary_logloss: 0.128632
# [40]	valid_0's binary_logloss: 0.125723
# [41]	valid_0's binary_logloss: 0.122978
# [42]	valid_0's binary_logloss: 0.120403
# [43]	valid_0's binary_logloss: 0.11798
# [44]	valid_0's binary_logloss: 0.115721
# [45]	valid_0's binary_logloss: 0.113588
# [46]	valid_0's binary_logloss: 0.111581
# [47]	valid_0's binary_logloss: 0.109709
# [48]	valid_0's binary_logloss: 0.107952
# [49]	valid_0's binary_logloss: 0.106298
# [50]	valid_0's binary_logloss: 0.104745
# [51]	valid_0's binary_logloss: 0.103299
# [52]	valid_0's binary_logloss: 0.101938
# [53]	valid_0's binary_logloss: 0.100658
# [54]	valid_0's binary_logloss: 0.0994619
# [55]	valid_0's binary_logloss: 0.0983436
# [56]	valid_0's binary_logloss: 0.0972876
# [57]	valid_0's binary_logloss: 0.0963094
# [58]	valid_0's binary_logloss: 0.0953937
# [59]	valid_0's binary_logloss: 0.0945293
# [60]	valid_0's binary_logloss: 0.0937251
# [61]	valid_0's binary_logloss: 0.0929703
# [62]	valid_0's binary_logloss: 0.0922665
# [63]	valid_0's binary_logloss: 0.0916161
# [64]	valid_0's binary_logloss: 0.0909925
# [65]	valid_0's binary_logloss: 0.0904214
# [66]	valid_0's binary_logloss: 0.0898832
# [67]	valid_0's binary_logloss: 0.0893818
# [68]	valid_0's binary_logloss: 0.088921
# [69]	valid_0's binary_logloss: 0.0884868
# [70]	valid_0's binary_logloss: 0.0880781
# [71]	valid_0's binary_logloss: 0.0877101
# [72]	valid_0's binary_logloss: 0.0873568
# [73]	valid_0's binary_logloss: 0.0870286
# [74]	valid_0's binary_logloss: 0.0867172
# [75]	valid_0's binary_logloss: 0.0864445
# [76]	valid_0's binary_logloss: 0.0861811
# [77]	valid_0's binary_logloss: 0.0859335
# [78]	valid_0's binary_logloss: 0.0857052
# [79]	valid_0's binary_logloss: 0.0854929
# [80]	valid_0's binary_logloss: 0.0852967
# [81]	valid_0's binary_logloss: 0.0851008
# [82]	valid_0's binary_logloss: 0.0849307
# [83]	valid_0's binary_logloss: 0.0847675
# [84]	valid_0's binary_logloss: 0.0846002
# [85]	valid_0's binary_logloss: 0.0844596
# [86]	valid_0's binary_logloss: 0.0843263
# [87]	valid_0's binary_logloss: 0.084203
# [88]	valid_0's binary_logloss: 0.0840913
# [89]	valid_0's binary_logloss: 0.0839804
# [90]	valid_0's binary_logloss: 0.0838803
# [91]	valid_0's binary_logloss: 0.0837879
# [92]	valid_0's binary_logloss: 0.0837008
# [93]	valid_0's binary_logloss: 0.0836148
# [94]	valid_0's binary_logloss: 0.0835358
# [95]	valid_0's binary_logloss: 0.0834557
# [96]	valid_0's binary_logloss: 0.0833911
# [97]	valid_0's binary_logloss: 0.0833323
# [98]	valid_0's binary_logloss: 0.0832824
# [99]	valid_0's binary_logloss: 0.0832223
# [100]	valid_0's binary_logloss: 0.0831682
# [101]	valid_0's binary_logloss: 0.0831243
# [102]	valid_0's binary_logloss: 0.0830765
# [103]	valid_0's binary_logloss: 0.0830293
# [104]	valid_0's binary_logloss: 0.0829911
# [105]	valid_0's binary_logloss: 0.0829567
# [106]	valid_0's binary_logloss: 0.0829163
# [107]	valid_0's binary_logloss: 0.082887
# [108]	valid_0's binary_logloss: 0.0828633
# [109]	valid_0's binary_logloss: 0.0828333
# [110]	valid_0's binary_logloss: 0.0828152
# [111]	valid_0's binary_logloss: 0.0827771
# [112]	valid_0's binary_logloss: 0.0827377
# [113]	valid_0's binary_logloss: 0.0827004
# [114]	valid_0's binary_logloss: 0.0826746
# [115]	valid_0's binary_logloss: 0.0826599
# [116]	valid_0's binary_logloss: 0.0826318
# [117]	valid_0's binary_logloss: 0.0826201
# [118]	valid_0's binary_logloss: 0.0825985
# [119]	valid_0's binary_logloss: 0.0825824
# [120]	valid_0's binary_logloss: 0.0825682
# [121]	valid_0's binary_logloss: 0.0825497
# [122]	valid_0's binary_logloss: 0.0825148
# [123]	valid_0's binary_logloss: 0.0824789
# [124]	valid_0's binary_logloss: 0.0824688
# [125]	valid_0's binary_logloss: 0.0824501
# [126]	valid_0's binary_logloss: 0.082443
# [127]	valid_0's binary_logloss: 0.0824342
# [128]	valid_0's binary_logloss: 0.0824212
# [129]	valid_0's binary_logloss: 0.0824176
# [130]	valid_0's binary_logloss: 0.0823969
# [131]	valid_0's binary_logloss: 0.0823961
# [132]	valid_0's binary_logloss: 0.0823886
# [133]	valid_0's binary_logloss: 0.0823733
# [134]	valid_0's binary_logloss: 0.082365
# [135]	valid_0's binary_logloss: 0.0823614
# [136]	valid_0's binary_logloss: 0.0823604
# [137]	valid_0's binary_logloss: 0.0823626
# [138]	valid_0's binary_logloss: 0.0823559
# [139]	valid_0's binary_logloss: 0.0823375
# [140]	valid_0's binary_logloss: 0.082329
# [141]	valid_0's binary_logloss: 0.0823367
# [142]	valid_0's binary_logloss: 0.0823347
# [143]	valid_0's binary_logloss: 0.0823212
# [144]	valid_0's binary_logloss: 0.0823219
# [145]	valid_0's binary_logloss: 0.0823202
# [146]	valid_0's binary_logloss: 0.0823109
# [147]	valid_0's binary_logloss: 0.0823094
# [148]	valid_0's binary_logloss: 0.0823009
# [149]	valid_0's binary_logloss: 0.0823017
# [150]	valid_0's binary_logloss: 0.0823043
# [151]	valid_0's binary_logloss: 0.0823114
# [152]	valid_0's binary_logloss: 0.082312
# [153]	valid_0's binary_logloss: 0.0823199
# [154]	valid_0's binary_logloss: 0.0822993
# [155]	valid_0's binary_logloss: 0.0822919
# [156]	valid_0's binary_logloss: 0.0822935
# [157]	valid_0's binary_logloss: 0.0822736
# [158]	valid_0's binary_logloss: 0.0822794
# [159]	valid_0's binary_logloss: 0.0822718
# [160]	valid_0's binary_logloss: 0.0822735
# [161]	valid_0's binary_logloss: 0.0822773
# [162]	valid_0's binary_logloss: 0.08228
# [163]	valid_0's binary_logloss: 0.0822716
# [164]	valid_0's binary_logloss: 0.0822753
# [165]	valid_0's binary_logloss: 0.0822807
# [166]	valid_0's binary_logloss: 0.0822775
# [167]	valid_0's binary_logloss: 0.0822824
# [168]	valid_0's binary_logloss: 0.0822792
# [169]	valid_0's binary_logloss: 0.082273
# [170]	valid_0's binary_logloss: 0.0822636
# [171]	valid_0's binary_logloss: 0.0822624
# [172]	valid_0's binary_logloss: 0.0822552
# [173]	valid_0's binary_logloss: 0.0822584
# [174]	valid_0's binary_logloss: 0.0822624
# [175]	valid_0's binary_logloss: 0.0822683
# [176]	valid_0's binary_logloss: 0.0822677
# [177]	valid_0's binary_logloss: 0.0822731
# [178]	valid_0's binary_logloss: 0.0822782
# [179]	valid_0's binary_logloss: 0.0822849
# [180]	valid_0's binary_logloss: 0.0822834
# [181]	valid_0's binary_logloss: 0.0822854
# [182]	valid_0's binary_logloss: 0.0822807
# [183]	valid_0's binary_logloss: 0.0822814
# [184]	valid_0's binary_logloss: 0.0822823
# [185]	valid_0's binary_logloss: 0.082288
# [186]	valid_0's binary_logloss: 0.0822973
# [187]	valid_0's binary_logloss: 0.082303
# [188]	valid_0's binary_logloss: 0.0823081
# [189]	valid_0's binary_logloss: 0.0823093
# [190]	valid_0's binary_logloss: 0.0823065
# [191]	valid_0's binary_logloss: 0.0823062
# [192]	valid_0's binary_logloss: 0.0823029
# [193]	valid_0's binary_logloss: 0.0822953
# [194]	valid_0's binary_logloss: 0.0822911
# [195]	valid_0's binary_logloss: 0.0822883
# [196]	valid_0's binary_logloss: 0.0822956
# [197]	valid_0's binary_logloss: 0.0823001
# [198]	valid_0's binary_logloss: 0.0822966
# [199]	valid_0's binary_logloss: 0.0822917
# [200]	valid_0's binary_logloss: 0.0822938
# [201]	valid_0's binary_logloss: 0.0823021
# [202]	valid_0's binary_logloss: 0.0823023
# [203]	valid_0's binary_logloss: 0.0823102
# [204]	valid_0's binary_logloss: 0.0823066
# [205]	valid_0's binary_logloss: 0.0823072
# [206]	valid_0's binary_logloss: 0.0823082
# [207]	valid_0's binary_logloss: 0.0823109
# [208]	valid_0's binary_logloss: 0.0823123
# [209]	valid_0's binary_logloss: 0.082312
# [210]	valid_0's binary_logloss: 0.0823088
# [211]	valid_0's binary_logloss: 0.082313
# [212]	valid_0's binary_logloss: 0.0823183
# [213]	valid_0's binary_logloss: 0.0823191
# [214]	valid_0's binary_logloss: 0.0823255
# [215]	valid_0's binary_logloss: 0.0823279
# [216]	valid_0's binary_logloss: 0.0823047
# [217]	valid_0's binary_logloss: 0.0823052
# [218]	valid_0's binary_logloss: 0.082306
# [219]	valid_0's binary_logloss: 0.0823118
# [220]	valid_0's binary_logloss: 0.0823124
# [221]	valid_0's binary_logloss: 0.0823134
# [222]	valid_0's binary_logloss: 0.08231
# [223]	valid_0's binary_logloss: 0.0823081
# [224]	valid_0's binary_logloss: 0.0823078
# [225]	valid_0's binary_logloss: 0.0823149
# [226]	valid_0's binary_logloss: 0.082319
# [227]	valid_0's binary_logloss: 0.0823196
# [228]	valid_0's binary_logloss: 0.0823168
# [229]	valid_0's binary_logloss: 0.0823205
# [230]	valid_0's binary_logloss: 0.082315
# [231]	valid_0's binary_logloss: 0.0823191
# [232]	valid_0's binary_logloss: 0.0823205
# [233]	valid_0's binary_logloss: 0.0823206
# [234]	valid_0's binary_logloss: 0.0823261
# [235]	valid_0's binary_logloss: 0.0823329
# [236]	valid_0's binary_logloss: 0.0823345
# [237]	valid_0's binary_logloss: 0.0823377
# [238]	valid_0's binary_logloss: 0.0823372
# [239]	valid_0's binary_logloss: 0.0823373
# [240]	valid_0's binary_logloss: 0.0823402
# [241]	valid_0's binary_logloss: 0.0823407
# [242]	valid_0's binary_logloss: 0.082342
# [243]	valid_0's binary_logloss: 0.0823474
# [244]	valid_0's binary_logloss: 0.082348
# [245]	valid_0's binary_logloss: 0.0823472
# [246]	valid_0's binary_logloss: 0.0823464
# [247]	valid_0's binary_logloss: 0.0823493
# [248]	valid_0's binary_logloss: 0.0823488
# [249]	valid_0's binary_logloss: 0.0823555
# [250]	valid_0's binary_logloss: 0.0823646
# [251]	valid_0's binary_logloss: 0.0823639
# [252]	valid_0's binary_logloss: 0.0823634
# [253]	valid_0's binary_logloss: 0.0823601
# [254]	valid_0's binary_logloss: 0.0823561
# [255]	valid_0's binary_logloss: 0.0823522
# [256]	valid_0's binary_logloss: 0.0823556
# [257]	valid_0's binary_logloss: 0.0823573
# [258]	valid_0's binary_logloss: 0.0823558
# [259]	valid_0's binary_logloss: 0.0823502
# [260]	valid_0's binary_logloss: 0.082355
# [261]	valid_0's binary_logloss: 0.0823613
# [262]	valid_0's binary_logloss: 0.0823667
# [263]	valid_0's binary_logloss: 0.082366
# [264]	valid_0's binary_logloss: 0.0823693
# [265]	valid_0's binary_logloss: 0.0823675
# [266]	valid_0's binary_logloss: 0.0823759
# [267]	valid_0's binary_logloss: 0.0823691
# [268]	valid_0's binary_logloss: 0.0823705
# [269]	valid_0's binary_logloss: 0.0823582
# [270]	valid_0's binary_logloss: 0.0823569
# [271]	valid_0's binary_logloss: 0.082361
# [272]	valid_0's binary_logloss: 0.082361
# [273]	valid_0's binary_logloss: 0.0823552
# [274]	valid_0's binary_logloss: 0.0823628
# [275]	valid_0's binary_logloss: 0.082366
# [276]	valid_0's binary_logloss: 0.0823662
# [277]	valid_0's binary_logloss: 0.0823676
# [278]	valid_0's binary_logloss: 0.0823735
# [279]	valid_0's binary_logloss: 0.0823732
# [280]	valid_0's binary_logloss: 0.082378
# [281]	valid_0's binary_logloss: 0.0823794
# [282]	valid_0's binary_logloss: 0.0823829
# [283]	valid_0's binary_logloss: 0.0823861
# [284]	valid_0's binary_logloss: 0.0823847
# [285]	valid_0's binary_logloss: 0.0823881
# [286]	valid_0's binary_logloss: 0.0823767
# [287]	valid_0's binary_logloss: 0.0823819
# [288]	valid_0's binary_logloss: 0.0823859
# [289]	valid_0's binary_logloss: 0.0823916
# [290]	valid_0's binary_logloss: 0.0823962
# [291]	valid_0's binary_logloss: 0.0824017
# [292]	valid_0's binary_logloss: 0.0823946
# [293]	valid_0's binary_logloss: 0.0823935
# [294]	valid_0's binary_logloss: 0.0823977
# [295]	valid_0's binary_logloss: 0.0823993
# [296]	valid_0's binary_logloss: 0.082407
# [297]	valid_0's binary_logloss: 0.0824113
# [298]	valid_0's binary_logloss: 0.0824122
# [299]	valid_0's binary_logloss: 0.0824202
# [300]	valid_0's binary_logloss: 0.0824196
# [301]	valid_0's binary_logloss: 0.0824145
# [302]	valid_0's binary_logloss: 0.0824151
# [303]	valid_0's binary_logloss: 0.0824144
# [304]	valid_0's binary_logloss: 0.0824085
# [305]	valid_0's binary_logloss: 0.082412
# [306]	valid_0's binary_logloss: 0.0824074
# [307]	valid_0's binary_logloss: 0.0824058
# [308]	valid_0's binary_logloss: 0.0824105
# [309]	valid_0's binary_logloss: 0.0824069
# [310]	valid_0's binary_logloss: 0.0824113
# [311]	valid_0's binary_logloss: 0.0824069
# [312]	valid_0's binary_logloss: 0.0824016
# [313]	valid_0's binary_logloss: 0.0824049
# [314]	valid_0's binary_logloss: 0.0824026
# [315]	valid_0's binary_logloss: 0.0824073
# [316]	valid_0's binary_logloss: 0.0824139
# [317]	valid_0's binary_logloss: 0.0824185
# [318]	valid_0's binary_logloss: 0.0824205
# [319]	valid_0's binary_logloss: 0.0824215
# [320]	valid_0's binary_logloss: 0.0824291
# [321]	valid_0's binary_logloss: 0.0824241
# [322]	valid_0's binary_logloss: 0.0824242
# [323]	valid_0's binary_logloss: 0.0824231
# [324]	valid_0's binary_logloss: 0.0824291
# [325]	valid_0's binary_logloss: 0.0824349
# [326]	valid_0's binary_logloss: 0.0824368
# [327]	valid_0's binary_logloss: 0.0824446
# [328]	valid_0's binary_logloss: 0.0824429
# [329]	valid_0's binary_logloss: 0.0824442
# [330]	valid_0's binary_logloss: 0.0824412
# [331]	valid_0's binary_logloss: 0.0824446
# [332]	valid_0's binary_logloss: 0.0824462
# [333]	valid_0's binary_logloss: 0.0824514
# [334]	valid_0's binary_logloss: 0.0824604
# [335]	valid_0's binary_logloss: 0.0824675
# [336]	valid_0's binary_logloss: 0.0824744
# [337]	valid_0's binary_logloss: 0.0824728
# [338]	valid_0's binary_logloss: 0.0824737
# [339]	valid_0's binary_logloss: 0.0824708
# [340]	valid_0's binary_logloss: 0.0824639
# [341]	valid_0's binary_logloss: 0.0824614
# [342]	valid_0's binary_logloss: 0.0824556
# [343]	valid_0's binary_logloss: 0.0824499
# [344]	valid_0's binary_logloss: 0.0824536
# [345]	valid_0's binary_logloss: 0.0824504
# [346]	valid_0's binary_logloss: 0.0824573
# [347]	valid_0's binary_logloss: 0.0824625
# [348]	valid_0's binary_logloss: 0.0824607
# [349]	valid_0's binary_logloss: 0.0824541
# [350]	valid_0's binary_logloss: 0.0824549
# [351]	valid_0's binary_logloss: 0.0824562
# [352]	valid_0's binary_logloss: 0.082458
# [353]	valid_0's binary_logloss: 0.0824651
# [354]	valid_0's binary_logloss: 0.0824586
# [355]	valid_0's binary_logloss: 0.0824591
# [356]	valid_0's binary_logloss: 0.08246
# [357]	valid_0's binary_logloss: 0.0824659
# [358]	valid_0's binary_logloss: 0.0824737
# [359]	valid_0's binary_logloss: 0.0824677
# [360]	valid_0's binary_logloss: 0.0824654
# [361]	valid_0's binary_logloss: 0.082455
# [362]	valid_0's binary_logloss: 0.0824561
# [363]	valid_0's binary_logloss: 0.0824597
# [364]	valid_0's binary_logloss: 0.0824516
# [365]	valid_0's binary_logloss: 0.0824578
# [366]	valid_0's binary_logloss: 0.0824561
# [367]	valid_0's binary_logloss: 0.0824592
# [368]	valid_0's binary_logloss: 0.0824662
# [369]	valid_0's binary_logloss: 0.0824657
# [370]	valid_0's binary_logloss: 0.0824687
# [371]	valid_0's binary_logloss: 0.0824739
# [372]	valid_0's binary_logloss: 0.0824744
# Early stopping, best iteration is:
# [172]	valid_0's binary_logloss: 0.0822552
# context_id                   642
# item_sales_level             482
# shop_score_delivery          450
# shop_score_service           314
# shop_score_description       293
# hour                         285
# shop_review_positive_rate    278
# context_page_id              249
# item_price_level             232
# avg_collected_brand          214
# instance_nums_shop           204
# item_collected_level         180
# user_age_level3              171
# category_1                   154
# item_per_shop                150
# item_nums_shop               144
# shop_review_num_level        137
# item_brand                   130
# shop_star_level              119
# item_pv_level                116
# instance_nums_brand          114
# user_star_level1             101
# fans_nums_shop                87
# item_nums_brand               84
# user_gender_id3               77
# fans_nums_brand               75
# shop_nums_brand               47
# user_nums_shop                45
# user_star_level2              39
# user_gender_id2               34
# user_age_level2               29
# user_nums_brand               27
# brand_nums_shop               26
# user_star_level3              25
# category_2                    18
# user_age_level1               15
# user_gender_id1               14
# shop_label1                   13
# brand_label7                   8
# user_occupation_id1            6
# brand_label3                   5
# brand_label5                   5
# user_occupation_id2            3
# shop_label2                    3
# brand_label1                   2
# brand_label6                   1
# shop_label3                    1
# brand_label4                   0
# brand_label2                   0
# dtype: int32
# (49,)
# 误差  -0.0822552481127
# KS  0.253146108721
# C:\Users\Leo Mao\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Leo Mao\Anaconda3\lib\site-packages\ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
col = [col for col in train.columns if col not in no_used+['is_trade']]
leaf = 35
trainTmp = train.loc[train['is_trade']==1]
train = pd.concat([train,trainTmp])
X = train[col]
y = train['is_trade'].values
X_tes = test[col]
y_tes = test['is_trade'].values
print('Training LGBM model...')
lgb0 = lgb.LGBMClassifier(
    objective='binary',
    # metric='binary_error',
    num_leaves=leaf,
    depth=8,
    learning_rate=0.05,
    seed=2018,
    colsample_bytree=0.8,
    # min_child_samples=8,
    subsample=0.9,
    n_estimators=20000)
lgb_model = lgb0.fit(X, y, eval_set=[(X_tes, y_tes)], early_stopping_rounds=200)
best_iter = lgb_model.best_iteration_
predictors = [i for i in X.columns]
feat_imp = pd.Series(lgb_model.feature_importances_, predictors).sort_values(ascending=False)
print(feat_imp)
print(feat_imp.shape)
# pred= lgb_model.predict(test[col])
pred = lgb_model.predict_proba(test[col])[:, 1]
test['pred'] = pred
test['index'] = range(len(test))
# print(test[['is_trade','pred']])
print('误差 ', log_loss(test['is_trade'], test['pred']))
print('KS ', ks_metric(test['is_trade'], test['pred']))
ks = ks_metric(test['is_trade'], test['pred'])
# Out:
# Training LGBM model...
# [1]	valid_0's binary_logloss: 0.649387
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's binary_logloss: 0.60971
# [3]	valid_0's binary_logloss: 0.573615
# [4]	valid_0's binary_logloss: 0.540675
# [5]	valid_0's binary_logloss: 0.510426
# [6]	valid_0's binary_logloss: 0.482628
# [7]	valid_0's binary_logloss: 0.457024
# [8]	valid_0's binary_logloss: 0.433358
# [9]	valid_0's binary_logloss: 0.411484
# [10]	valid_0's binary_logloss: 0.391201
# [11]	valid_0's binary_logloss: 0.372378
# [12]	valid_0's binary_logloss: 0.354895
# [13]	valid_0's binary_logloss: 0.338609
# [14]	valid_0's binary_logloss: 0.323411
# [15]	valid_0's binary_logloss: 0.30924
# [16]	valid_0's binary_logloss: 0.295999
# [17]	valid_0's binary_logloss: 0.283636
# [18]	valid_0's binary_logloss: 0.272052
# [19]	valid_0's binary_logloss: 0.261222
# [20]	valid_0's binary_logloss: 0.251076
# [21]	valid_0's binary_logloss: 0.241566
# [22]	valid_0's binary_logloss: 0.232648
# [23]	valid_0's binary_logloss: 0.224289
# [24]	valid_0's binary_logloss: 0.216432
# [25]	valid_0's binary_logloss: 0.209045
# [26]	valid_0's binary_logloss: 0.202117
# [27]	valid_0's binary_logloss: 0.195596
# [28]	valid_0's binary_logloss: 0.189456
# [29]	valid_0's binary_logloss: 0.183681
# [30]	valid_0's binary_logloss: 0.178244
# [31]	valid_0's binary_logloss: 0.173147
# [32]	valid_0's binary_logloss: 0.168358
# [33]	valid_0's binary_logloss: 0.163839
# [34]	valid_0's binary_logloss: 0.159574
# [35]	valid_0's binary_logloss: 0.155576
# [36]	valid_0's binary_logloss: 0.151789
# [37]	valid_0's binary_logloss: 0.14821
# [38]	valid_0's binary_logloss: 0.14486
# [39]	valid_0's binary_logloss: 0.141724
# [40]	valid_0's binary_logloss: 0.138752
# [41]	valid_0's binary_logloss: 0.135943
# [42]	valid_0's binary_logloss: 0.133314
# [43]	valid_0's binary_logloss: 0.130816
# [44]	valid_0's binary_logloss: 0.128469
# [45]	valid_0's binary_logloss: 0.126255
# [46]	valid_0's binary_logloss: 0.124168
# [47]	valid_0's binary_logloss: 0.122204
# [48]	valid_0's binary_logloss: 0.120354
# [49]	valid_0's binary_logloss: 0.118603
# [50]	valid_0's binary_logloss: 0.116953
# [51]	valid_0's binary_logloss: 0.115408
# [52]	valid_0's binary_logloss: 0.113943
# [53]	valid_0's binary_logloss: 0.112546
# [54]	valid_0's binary_logloss: 0.111241
# [55]	valid_0's binary_logloss: 0.110015
# [56]	valid_0's binary_logloss: 0.108848
# [57]	valid_0's binary_logloss: 0.107758
# [58]	valid_0's binary_logloss: 0.106723
# [59]	valid_0's binary_logloss: 0.10576
# [60]	valid_0's binary_logloss: 0.104843
# [61]	valid_0's binary_logloss: 0.103965
# [62]	valid_0's binary_logloss: 0.10316
# [63]	valid_0's binary_logloss: 0.102392
# [64]	valid_0's binary_logloss: 0.101659
# [65]	valid_0's binary_logloss: 0.100969
# [66]	valid_0's binary_logloss: 0.100315
# [67]	valid_0's binary_logloss: 0.0996929
# [68]	valid_0's binary_logloss: 0.0991032
# [69]	valid_0's binary_logloss: 0.0985506
# [70]	valid_0's binary_logloss: 0.0980431
# [71]	valid_0's binary_logloss: 0.0975602
# [72]	valid_0's binary_logloss: 0.0970949
# [73]	valid_0's binary_logloss: 0.0966667
# [74]	valid_0's binary_logloss: 0.0962415
# [75]	valid_0's binary_logloss: 0.0958427
# [76]	valid_0's binary_logloss: 0.0954743
# [77]	valid_0's binary_logloss: 0.0951066
# [78]	valid_0's binary_logloss: 0.0947904
# [79]	valid_0's binary_logloss: 0.0944843
# [80]	valid_0's binary_logloss: 0.0942045
# [81]	valid_0's binary_logloss: 0.0939334
# [82]	valid_0's binary_logloss: 0.0936748
# [83]	valid_0's binary_logloss: 0.0934287
# [84]	valid_0's binary_logloss: 0.0932039
# [85]	valid_0's binary_logloss: 0.0929737
# [86]	valid_0's binary_logloss: 0.0927719
# [87]	valid_0's binary_logloss: 0.092569
# [88]	valid_0's binary_logloss: 0.0923921
# [89]	valid_0's binary_logloss: 0.0922177
# [90]	valid_0's binary_logloss: 0.0920442
# [91]	valid_0's binary_logloss: 0.0918885
# [92]	valid_0's binary_logloss: 0.0917346
# [93]	valid_0's binary_logloss: 0.0915784
# [94]	valid_0's binary_logloss: 0.0914471
# [95]	valid_0's binary_logloss: 0.0913152
# [96]	valid_0's binary_logloss: 0.0911991
# [97]	valid_0's binary_logloss: 0.0910698
# [98]	valid_0's binary_logloss: 0.0909676
# [99]	valid_0's binary_logloss: 0.0908614
# [100]	valid_0's binary_logloss: 0.0907583
# [101]	valid_0's binary_logloss: 0.0906593
# [102]	valid_0's binary_logloss: 0.0905719
# [103]	valid_0's binary_logloss: 0.0904837
# [104]	valid_0's binary_logloss: 0.0903887
# [105]	valid_0's binary_logloss: 0.0903075
# [106]	valid_0's binary_logloss: 0.0902274
# [107]	valid_0's binary_logloss: 0.0901468
# [108]	valid_0's binary_logloss: 0.0900811
# [109]	valid_0's binary_logloss: 0.0900203
# [110]	valid_0's binary_logloss: 0.089967
# [111]	valid_0's binary_logloss: 0.0899072
# [112]	valid_0's binary_logloss: 0.0898391
# [113]	valid_0's binary_logloss: 0.0897896
# [114]	valid_0's binary_logloss: 0.0897319
# [115]	valid_0's binary_logloss: 0.0896986
# [116]	valid_0's binary_logloss: 0.0896658
# [117]	valid_0's binary_logloss: 0.0896218
# [118]	valid_0's binary_logloss: 0.0895772
# [119]	valid_0's binary_logloss: 0.0895418
# [120]	valid_0's binary_logloss: 0.0894981
# [121]	valid_0's binary_logloss: 0.089468
# [122]	valid_0's binary_logloss: 0.0894302
# [123]	valid_0's binary_logloss: 0.0893921
# [124]	valid_0's binary_logloss: 0.0893394
# [125]	valid_0's binary_logloss: 0.0893179
# [126]	valid_0's binary_logloss: 0.0892828
# [127]	valid_0's binary_logloss: 0.0892546
# [128]	valid_0's binary_logloss: 0.0892216
# [129]	valid_0's binary_logloss: 0.0892106
# [130]	valid_0's binary_logloss: 0.0891963
# [131]	valid_0's binary_logloss: 0.0891828
# [132]	valid_0's binary_logloss: 0.0891586
# [133]	valid_0's binary_logloss: 0.0891389
# [134]	valid_0's binary_logloss: 0.0891118
# [135]	valid_0's binary_logloss: 0.0890882
# [136]	valid_0's binary_logloss: 0.0890756
# [137]	valid_0's binary_logloss: 0.0890691
# [138]	valid_0's binary_logloss: 0.0890604
# [139]	valid_0's binary_logloss: 0.0890433
# [140]	valid_0's binary_logloss: 0.0890169
# [141]	valid_0's binary_logloss: 0.0890033
# [142]	valid_0's binary_logloss: 0.0889969
# [143]	valid_0's binary_logloss: 0.0889821
# [144]	valid_0's binary_logloss: 0.0889726
# [145]	valid_0's binary_logloss: 0.0889584
# [146]	valid_0's binary_logloss: 0.0889585
# [147]	valid_0's binary_logloss: 0.0889342
# [148]	valid_0's binary_logloss: 0.0889282
# [149]	valid_0's binary_logloss: 0.0889122
# [150]	valid_0's binary_logloss: 0.0888947
# [151]	valid_0's binary_logloss: 0.0888904
# [152]	valid_0's binary_logloss: 0.0888841
# [153]	valid_0's binary_logloss: 0.0888754
# [154]	valid_0's binary_logloss: 0.0888766
# [155]	valid_0's binary_logloss: 0.0888636
# [156]	valid_0's binary_logloss: 0.0888472
# [157]	valid_0's binary_logloss: 0.0888391
# [158]	valid_0's binary_logloss: 0.088835
# [159]	valid_0's binary_logloss: 0.0888279
# [160]	valid_0's binary_logloss: 0.0888249
# [161]	valid_0's binary_logloss: 0.0888214
# [162]	valid_0's binary_logloss: 0.0888186
# [163]	valid_0's binary_logloss: 0.0888183
# [164]	valid_0's binary_logloss: 0.0887944
# [165]	valid_0's binary_logloss: 0.0887815
# [166]	valid_0's binary_logloss: 0.0887813
# [167]	valid_0's binary_logloss: 0.0887838
# [168]	valid_0's binary_logloss: 0.0887828
# [169]	valid_0's binary_logloss: 0.0887778
# [170]	valid_0's binary_logloss: 0.0887711
# [171]	valid_0's binary_logloss: 0.0887817
# [172]	valid_0's binary_logloss: 0.0887764
# [173]	valid_0's binary_logloss: 0.0887694
# [174]	valid_0's binary_logloss: 0.0887579
# [175]	valid_0's binary_logloss: 0.0887605
# [176]	valid_0's binary_logloss: 0.0887504
# [177]	valid_0's binary_logloss: 0.0887474
# [178]	valid_0's binary_logloss: 0.0887491
# [179]	valid_0's binary_logloss: 0.088746
# [180]	valid_0's binary_logloss: 0.0887461
# [181]	valid_0's binary_logloss: 0.088748
# [182]	valid_0's binary_logloss: 0.0887582
# [183]	valid_0's binary_logloss: 0.0887532
# [184]	valid_0's binary_logloss: 0.0887514
# [185]	valid_0's binary_logloss: 0.0887341
# [186]	valid_0's binary_logloss: 0.0887264
# [187]	valid_0's binary_logloss: 0.0887296
# [188]	valid_0's binary_logloss: 0.08873
# [189]	valid_0's binary_logloss: 0.0887398
# [190]	valid_0's binary_logloss: 0.0887382
# [191]	valid_0's binary_logloss: 0.0887337
# [192]	valid_0's binary_logloss: 0.0887416
# [193]	valid_0's binary_logloss: 0.088736
# [194]	valid_0's binary_logloss: 0.0887329
# [195]	valid_0's binary_logloss: 0.0887365
# [196]	valid_0's binary_logloss: 0.0887304
# [197]	valid_0's binary_logloss: 0.088733
# [198]	valid_0's binary_logloss: 0.0887284
# [199]	valid_0's binary_logloss: 0.0887287
# [200]	valid_0's binary_logloss: 0.0887148
# [201]	valid_0's binary_logloss: 0.0887175
# [202]	valid_0's binary_logloss: 0.0887151
# [203]	valid_0's binary_logloss: 0.0887115
# [204]	valid_0's binary_logloss: 0.0887173
# [205]	valid_0's binary_logloss: 0.0887133
# [206]	valid_0's binary_logloss: 0.0887089
# [207]	valid_0's binary_logloss: 0.0887054
# [208]	valid_0's binary_logloss: 0.0887094
# [209]	valid_0's binary_logloss: 0.0887051
# [210]	valid_0's binary_logloss: 0.0887007
# [211]	valid_0's binary_logloss: 0.0887021
# [212]	valid_0's binary_logloss: 0.088685
# [213]	valid_0's binary_logloss: 0.0886914
# [214]	valid_0's binary_logloss: 0.0886789
# [215]	valid_0's binary_logloss: 0.0886764
# [216]	valid_0's binary_logloss: 0.0886654
# [217]	valid_0's binary_logloss: 0.0886739
# [218]	valid_0's binary_logloss: 0.0886748
# [219]	valid_0's binary_logloss: 0.0886674
# [220]	valid_0's binary_logloss: 0.0886674
# [221]	valid_0's binary_logloss: 0.0886738
# [222]	valid_0's binary_logloss: 0.0886738
# [223]	valid_0's binary_logloss: 0.0886737
# [224]	valid_0's binary_logloss: 0.0886684
# [225]	valid_0's binary_logloss: 0.0886683
# [226]	valid_0's binary_logloss: 0.0886695
# [227]	valid_0's binary_logloss: 0.0886593
# [228]	valid_0's binary_logloss: 0.0886533
# [229]	valid_0's binary_logloss: 0.0886561
# [230]	valid_0's binary_logloss: 0.0886582
# [231]	valid_0's binary_logloss: 0.0886513
# [232]	valid_0's binary_logloss: 0.0886446
# [233]	valid_0's binary_logloss: 0.0886392
# [234]	valid_0's binary_logloss: 0.0886479
# [235]	valid_0's binary_logloss: 0.0886526
# [236]	valid_0's binary_logloss: 0.0886551
# [237]	valid_0's binary_logloss: 0.0886557
# [238]	valid_0's binary_logloss: 0.0886517
# [239]	valid_0's binary_logloss: 0.088654
# [240]	valid_0's binary_logloss: 0.088648
# [241]	valid_0's binary_logloss: 0.0886502
# [242]	valid_0's binary_logloss: 0.088647
# [243]	valid_0's binary_logloss: 0.0886505
# [244]	valid_0's binary_logloss: 0.0886557
# [245]	valid_0's binary_logloss: 0.0886505
# [246]	valid_0's binary_logloss: 0.0886464
# [247]	valid_0's binary_logloss: 0.0886453
# [248]	valid_0's binary_logloss: 0.0886489
# [249]	valid_0's binary_logloss: 0.0886502
# [250]	valid_0's binary_logloss: 0.0886441
# [251]	valid_0's binary_logloss: 0.0886445
# [252]	valid_0's binary_logloss: 0.0886452
# [253]	valid_0's binary_logloss: 0.0886487
# [254]	valid_0's binary_logloss: 0.0886442
# [255]	valid_0's binary_logloss: 0.0886425
# [256]	valid_0's binary_logloss: 0.0886402
# [257]	valid_0's binary_logloss: 0.0886294
# [258]	valid_0's binary_logloss: 0.0886302
# [259]	valid_0's binary_logloss: 0.0886335
# [260]	valid_0's binary_logloss: 0.0886381
# [261]	valid_0's binary_logloss: 0.0886349
# [262]	valid_0's binary_logloss: 0.088632
# [263]	valid_0's binary_logloss: 0.0886402
# [264]	valid_0's binary_logloss: 0.0886437
# [265]	valid_0's binary_logloss: 0.0886428
# [266]	valid_0's binary_logloss: 0.08864
# [267]	valid_0's binary_logloss: 0.0886309
# [268]	valid_0's binary_logloss: 0.088639
# [269]	valid_0's binary_logloss: 0.0886336
# [270]	valid_0's binary_logloss: 0.0886334
# [271]	valid_0's binary_logloss: 0.0886488
# [272]	valid_0's binary_logloss: 0.0886442
# [273]	valid_0's binary_logloss: 0.0886402
# [274]	valid_0's binary_logloss: 0.0886334
# [275]	valid_0's binary_logloss: 0.0886257
# [276]	valid_0's binary_logloss: 0.0886277
# [277]	valid_0's binary_logloss: 0.0886347
# [278]	valid_0's binary_logloss: 0.0886393
# [279]	valid_0's binary_logloss: 0.0886294
# [280]	valid_0's binary_logloss: 0.0886301
# [281]	valid_0's binary_logloss: 0.0886315
# [282]	valid_0's binary_logloss: 0.0886339
# [283]	valid_0's binary_logloss: 0.0886324
# [284]	valid_0's binary_logloss: 0.08863
# [285]	valid_0's binary_logloss: 0.0886277
# [286]	valid_0's binary_logloss: 0.0886253
# [287]	valid_0's binary_logloss: 0.0886255
# [288]	valid_0's binary_logloss: 0.088621
# [289]	valid_0's binary_logloss: 0.0886174
# [290]	valid_0's binary_logloss: 0.0886156
# [291]	valid_0's binary_logloss: 0.0886132
# [292]	valid_0's binary_logloss: 0.0886121
# [293]	valid_0's binary_logloss: 0.0886053
# [294]	valid_0's binary_logloss: 0.0886055
# [295]	valid_0's binary_logloss: 0.0886094
# [296]	valid_0's binary_logloss: 0.0886113
# [297]	valid_0's binary_logloss: 0.0886041
# [298]	valid_0's binary_logloss: 0.0886025
# [299]	valid_0's binary_logloss: 0.0886006
# [300]	valid_0's binary_logloss: 0.088596
# [301]	valid_0's binary_logloss: 0.0885932
# [302]	valid_0's binary_logloss: 0.0885901
# [303]	valid_0's binary_logloss: 0.0885836
# [304]	valid_0's binary_logloss: 0.0885853
# [305]	valid_0's binary_logloss: 0.0885787
# [306]	valid_0's binary_logloss: 0.0885828
# [307]	valid_0's binary_logloss: 0.0885778
# [308]	valid_0's binary_logloss: 0.0885657
# [309]	valid_0's binary_logloss: 0.0885633
# [310]	valid_0's binary_logloss: 0.0885654
# [311]	valid_0's binary_logloss: 0.0885701
# [312]	valid_0's binary_logloss: 0.0885638
# [313]	valid_0's binary_logloss: 0.0885652
# [314]	valid_0's binary_logloss: 0.0885553
# [315]	valid_0's binary_logloss: 0.0885489
# [316]	valid_0's binary_logloss: 0.0885582
# [317]	valid_0's binary_logloss: 0.0885584
# [318]	valid_0's binary_logloss: 0.0885496
# [319]	valid_0's binary_logloss: 0.0885469
# [320]	valid_0's binary_logloss: 0.0885524
# [321]	valid_0's binary_logloss: 0.0885502
# [322]	valid_0's binary_logloss: 0.0885412
# [323]	valid_0's binary_logloss: 0.0885441
# [324]	valid_0's binary_logloss: 0.088553
# [325]	valid_0's binary_logloss: 0.0885518
# [326]	valid_0's binary_logloss: 0.0885396
# [327]	valid_0's binary_logloss: 0.088548
# [328]	valid_0's binary_logloss: 0.0885461
# [329]	valid_0's binary_logloss: 0.0885451
# [330]	valid_0's binary_logloss: 0.0885441
# [331]	valid_0's binary_logloss: 0.0885361
# [332]	valid_0's binary_logloss: 0.0885355
# [333]	valid_0's binary_logloss: 0.0885341
# [334]	valid_0's binary_logloss: 0.0885329
# [335]	valid_0's binary_logloss: 0.0885305
# [336]	valid_0's binary_logloss: 0.0885246
# [337]	valid_0's binary_logloss: 0.0885204
# [338]	valid_0's binary_logloss: 0.0885222
# [339]	valid_0's binary_logloss: 0.088516
# [340]	valid_0's binary_logloss: 0.0885137
# [341]	valid_0's binary_logloss: 0.0885117
# [342]	valid_0's binary_logloss: 0.0885134
# [343]	valid_0's binary_logloss: 0.0885129
# [344]	valid_0's binary_logloss: 0.0885164
# [345]	valid_0's binary_logloss: 0.0885177
# [346]	valid_0's binary_logloss: 0.0885132
# [347]	valid_0's binary_logloss: 0.0885123
# [348]	valid_0's binary_logloss: 0.088503
# [349]	valid_0's binary_logloss: 0.0884965
# [350]	valid_0's binary_logloss: 0.0884972
# [351]	valid_0's binary_logloss: 0.0884885
# [352]	valid_0's binary_logloss: 0.0884867
# [353]	valid_0's binary_logloss: 0.0884835
# [354]	valid_0's binary_logloss: 0.0884855
# [355]	valid_0's binary_logloss: 0.0884871
# [356]	valid_0's binary_logloss: 0.0884927
# [357]	valid_0's binary_logloss: 0.088489
# [358]	valid_0's binary_logloss: 0.0884895
# [359]	valid_0's binary_logloss: 0.0884944
# [360]	valid_0's binary_logloss: 0.0884898
# [361]	valid_0's binary_logloss: 0.0884907
# [362]	valid_0's binary_logloss: 0.088494
# [363]	valid_0's binary_logloss: 0.0884958
# [364]	valid_0's binary_logloss: 0.0884931
# [365]	valid_0's binary_logloss: 0.0885
# [366]	valid_0's binary_logloss: 0.0885059
# [367]	valid_0's binary_logloss: 0.0885007
# [368]	valid_0's binary_logloss: 0.0885019
# [369]	valid_0's binary_logloss: 0.0885011
# [370]	valid_0's binary_logloss: 0.0885049
# [371]	valid_0's binary_logloss: 0.0885031
# [372]	valid_0's binary_logloss: 0.0885103
# [373]	valid_0's binary_logloss: 0.0885134
# [374]	valid_0's binary_logloss: 0.0885105
# [375]	valid_0's binary_logloss: 0.0885119
# [376]	valid_0's binary_logloss: 0.0885099
# [377]	valid_0's binary_logloss: 0.088498
# [378]	valid_0's binary_logloss: 0.0885019
# [379]	valid_0's binary_logloss: 0.0884968
# [380]	valid_0's binary_logloss: 0.0885
# [381]	valid_0's binary_logloss: 0.0885024
# [382]	valid_0's binary_logloss: 0.0885033
# [383]	valid_0's binary_logloss: 0.0885084
# [384]	valid_0's binary_logloss: 0.0885074
# [385]	valid_0's binary_logloss: 0.0885106
# [386]	valid_0's binary_logloss: 0.0885105
# [387]	valid_0's binary_logloss: 0.0885141
# [388]	valid_0's binary_logloss: 0.0885205
# [389]	valid_0's binary_logloss: 0.088526
# [390]	valid_0's binary_logloss: 0.0885188
# [391]	valid_0's binary_logloss: 0.0885142
# [392]	valid_0's binary_logloss: 0.0885175
# [393]	valid_0's binary_logloss: 0.0885138
# [394]	valid_0's binary_logloss: 0.0885088
# [395]	valid_0's binary_logloss: 0.0885045
# [396]	valid_0's binary_logloss: 0.0885056
# [397]	valid_0's binary_logloss: 0.0885172
# [398]	valid_0's binary_logloss: 0.0885091
# [399]	valid_0's binary_logloss: 0.0884987
# [400]	valid_0's binary_logloss: 0.0884912
# [401]	valid_0's binary_logloss: 0.088483
# [402]	valid_0's binary_logloss: 0.0884846
# [403]	valid_0's binary_logloss: 0.0884791
# [404]	valid_0's binary_logloss: 0.0884819
# [405]	valid_0's binary_logloss: 0.0884786
# [406]	valid_0's binary_logloss: 0.0884827
# [407]	valid_0's binary_logloss: 0.0884802
# [408]	valid_0's binary_logloss: 0.0884873
# [409]	valid_0's binary_logloss: 0.0884845
# [410]	valid_0's binary_logloss: 0.0884883
# [411]	valid_0's binary_logloss: 0.0884773
# [412]	valid_0's binary_logloss: 0.0884774
# [413]	valid_0's binary_logloss: 0.0884731
# [414]	valid_0's binary_logloss: 0.0884746
# [415]	valid_0's binary_logloss: 0.0884673
# [416]	valid_0's binary_logloss: 0.0884635
# [417]	valid_0's binary_logloss: 0.0884669
# [418]	valid_0's binary_logloss: 0.0884692
# [419]	valid_0's binary_logloss: 0.0884706
# [420]	valid_0's binary_logloss: 0.0884651
# [421]	valid_0's binary_logloss: 0.0884597
# [422]	valid_0's binary_logloss: 0.0884542
# [423]	valid_0's binary_logloss: 0.0884492
# [424]	valid_0's binary_logloss: 0.0884513
# [425]	valid_0's binary_logloss: 0.088459
# [426]	valid_0's binary_logloss: 0.0884485
# [427]	valid_0's binary_logloss: 0.0884469
# [428]	valid_0's binary_logloss: 0.0884578
# [429]	valid_0's binary_logloss: 0.0884586
# [430]	valid_0's binary_logloss: 0.0884683
# [431]	valid_0's binary_logloss: 0.0884692
# [432]	valid_0's binary_logloss: 0.0884556
# [433]	valid_0's binary_logloss: 0.08846
# [434]	valid_0's binary_logloss: 0.0884607
# [435]	valid_0's binary_logloss: 0.0884586
# [436]	valid_0's binary_logloss: 0.0884618
# [437]	valid_0's binary_logloss: 0.0884549
# [438]	valid_0's binary_logloss: 0.0884495
# [439]	valid_0's binary_logloss: 0.088443
# [440]	valid_0's binary_logloss: 0.0884477
# [441]	valid_0's binary_logloss: 0.0884482
# [442]	valid_0's binary_logloss: 0.0884459
# [443]	valid_0's binary_logloss: 0.0884447
# [444]	valid_0's binary_logloss: 0.0884506
# [445]	valid_0's binary_logloss: 0.0884541
# [446]	valid_0's binary_logloss: 0.0884579
# [447]	valid_0's binary_logloss: 0.0884546
# [448]	valid_0's binary_logloss: 0.0884475
# [449]	valid_0's binary_logloss: 0.0884453
# [450]	valid_0's binary_logloss: 0.0884531
# [451]	valid_0's binary_logloss: 0.0884556
# [452]	valid_0's binary_logloss: 0.0884487
# [453]	valid_0's binary_logloss: 0.0884484
# [454]	valid_0's binary_logloss: 0.088451
# [455]	valid_0's binary_logloss: 0.088449
# [456]	valid_0's binary_logloss: 0.0884457
# [457]	valid_0's binary_logloss: 0.0884534
# [458]	valid_0's binary_logloss: 0.0884566
# [459]	valid_0's binary_logloss: 0.0884544
# [460]	valid_0's binary_logloss: 0.0884538
# [461]	valid_0's binary_logloss: 0.0884571
# [462]	valid_0's binary_logloss: 0.0884548
# [463]	valid_0's binary_logloss: 0.0884603
# [464]	valid_0's binary_logloss: 0.088462
# [465]	valid_0's binary_logloss: 0.0884649
# [466]	valid_0's binary_logloss: 0.0884725
# [467]	valid_0's binary_logloss: 0.0884732
# [468]	valid_0's binary_logloss: 0.0884671
# [469]	valid_0's binary_logloss: 0.0884685
# [470]	valid_0's binary_logloss: 0.0884646
# [471]	valid_0's binary_logloss: 0.0884646
# [472]	valid_0's binary_logloss: 0.0884577
# [473]	valid_0's binary_logloss: 0.0884531
# [474]	valid_0's binary_logloss: 0.0884503
# [475]	valid_0's binary_logloss: 0.0884559
# [476]	valid_0's binary_logloss: 0.0884558
# [477]	valid_0's binary_logloss: 0.0884529
# [478]	valid_0's binary_logloss: 0.0884456
# [479]	valid_0's binary_logloss: 0.0884428
# [480]	valid_0's binary_logloss: 0.0884434
# [481]	valid_0's binary_logloss: 0.0884411
# [482]	valid_0's binary_logloss: 0.0884369
# [483]	valid_0's binary_logloss: 0.088447
# [484]	valid_0's binary_logloss: 0.0884501
# [485]	valid_0's binary_logloss: 0.0884487
# [486]	valid_0's binary_logloss: 0.0884445
# [487]	valid_0's binary_logloss: 0.0884424
# [488]	valid_0's binary_logloss: 0.0884223
# [489]	valid_0's binary_logloss: 0.0884261
# [490]	valid_0's binary_logloss: 0.0884269
# [491]	valid_0's binary_logloss: 0.0884315
# [492]	valid_0's binary_logloss: 0.0884299
# [493]	valid_0's binary_logloss: 0.0884273
# [494]	valid_0's binary_logloss: 0.0884269
# [495]	valid_0's binary_logloss: 0.088425
# [496]	valid_0's binary_logloss: 0.0884354
# [497]	valid_0's binary_logloss: 0.0884357
# [498]	valid_0's binary_logloss: 0.0884346
# [499]	valid_0's binary_logloss: 0.0884348
# [500]	valid_0's binary_logloss: 0.0884291
# [501]	valid_0's binary_logloss: 0.0884333
# [502]	valid_0's binary_logloss: 0.0884379
# [503]	valid_0's binary_logloss: 0.0884314
# [504]	valid_0's binary_logloss: 0.0884295
# [505]	valid_0's binary_logloss: 0.0884257
# [506]	valid_0's binary_logloss: 0.0884213
# [507]	valid_0's binary_logloss: 0.0884227
# [508]	valid_0's binary_logloss: 0.0884244
# [509]	valid_0's binary_logloss: 0.0884302
# [510]	valid_0's binary_logloss: 0.0884384
# [511]	valid_0's binary_logloss: 0.0884382
# [512]	valid_0's binary_logloss: 0.0884388
# [513]	valid_0's binary_logloss: 0.0884402
# [514]	valid_0's binary_logloss: 0.0884306
# [515]	valid_0's binary_logloss: 0.0884321
# [516]	valid_0's binary_logloss: 0.0884405
# [517]	valid_0's binary_logloss: 0.0884383
# [518]	valid_0's binary_logloss: 0.0884325
# [519]	valid_0's binary_logloss: 0.0884385
# [520]	valid_0's binary_logloss: 0.0884336
# [521]	valid_0's binary_logloss: 0.0884312
# [522]	valid_0's binary_logloss: 0.0884348
# [523]	valid_0's binary_logloss: 0.0884337
# [524]	valid_0's binary_logloss: 0.0884407
# [525]	valid_0's binary_logloss: 0.0884447
# [526]	valid_0's binary_logloss: 0.0884416
# [527]	valid_0's binary_logloss: 0.0884403
# [528]	valid_0's binary_logloss: 0.0884354
# [529]	valid_0's binary_logloss: 0.088446
# [530]	valid_0's binary_logloss: 0.0884453
# [531]	valid_0's binary_logloss: 0.0884446
# [532]	valid_0's binary_logloss: 0.0884489
# [533]	valid_0's binary_logloss: 0.0884464
# [534]	valid_0's binary_logloss: 0.0884467
# [535]	valid_0's binary_logloss: 0.0884423
# [536]	valid_0's binary_logloss: 0.0884401
# [537]	valid_0's binary_logloss: 0.0884393
# [538]	valid_0's binary_logloss: 0.0884426
# [539]	valid_0's binary_logloss: 0.0884452
# [540]	valid_0's binary_logloss: 0.0884329
# [541]	valid_0's binary_logloss: 0.0884414
# [542]	valid_0's binary_logloss: 0.088428
# [543]	valid_0's binary_logloss: 0.0884355
# [544]	valid_0's binary_logloss: 0.0884314
# [545]	valid_0's binary_logloss: 0.0884311
# [546]	valid_0's binary_logloss: 0.0884329
# [547]	valid_0's binary_logloss: 0.0884317
# [548]	valid_0's binary_logloss: 0.088431
# [549]	valid_0's binary_logloss: 0.0884296
# [550]	valid_0's binary_logloss: 0.0884274
# [551]	valid_0's binary_logloss: 0.0884302
# [552]	valid_0's binary_logloss: 0.0884275
# [553]	valid_0's binary_logloss: 0.088424
# [554]	valid_0's binary_logloss: 0.0884197
# [555]	valid_0's binary_logloss: 0.0884268
# [556]	valid_0's binary_logloss: 0.088431
# [557]	valid_0's binary_logloss: 0.0884335
# [558]	valid_0's binary_logloss: 0.088426
# [559]	valid_0's binary_logloss: 0.0884226
# [560]	valid_0's binary_logloss: 0.0884266
# [561]	valid_0's binary_logloss: 0.08843
# [562]	valid_0's binary_logloss: 0.088427
# [563]	valid_0's binary_logloss: 0.0884265
# [564]	valid_0's binary_logloss: 0.0884275
# [565]	valid_0's binary_logloss: 0.0884181
# [566]	valid_0's binary_logloss: 0.0884133
# [567]	valid_0's binary_logloss: 0.0884215
# [568]	valid_0's binary_logloss: 0.0884209
# [569]	valid_0's binary_logloss: 0.0884211
# [570]	valid_0's binary_logloss: 0.0884152
# [571]	valid_0's binary_logloss: 0.0884146
# [572]	valid_0's binary_logloss: 0.0884142
# [573]	valid_0's binary_logloss: 0.0884137
# [574]	valid_0's binary_logloss: 0.0884154
# [575]	valid_0's binary_logloss: 0.0884102
# [576]	valid_0's binary_logloss: 0.0884003
# [577]	valid_0's binary_logloss: 0.0883958
# [578]	valid_0's binary_logloss: 0.088398
# [579]	valid_0's binary_logloss: 0.0883951
# [580]	valid_0's binary_logloss: 0.0883979
# [581]	valid_0's binary_logloss: 0.0884
# [582]	valid_0's binary_logloss: 0.0883973
# [583]	valid_0's binary_logloss: 0.0883979
# [584]	valid_0's binary_logloss: 0.088403
# [585]	valid_0's binary_logloss: 0.0884037
# [586]	valid_0's binary_logloss: 0.0883978
# [587]	valid_0's binary_logloss: 0.0883955
# [588]	valid_0's binary_logloss: 0.0884008
# [589]	valid_0's binary_logloss: 0.0883924
# [590]	valid_0's binary_logloss: 0.0883916
# [591]	valid_0's binary_logloss: 0.0883991
# [592]	valid_0's binary_logloss: 0.0884002
# [593]	valid_0's binary_logloss: 0.0883998
# [594]	valid_0's binary_logloss: 0.0884005
# [595]	valid_0's binary_logloss: 0.088399
# [596]	valid_0's binary_logloss: 0.0884038
# [597]	valid_0's binary_logloss: 0.0883976
# [598]	valid_0's binary_logloss: 0.0883969
# [599]	valid_0's binary_logloss: 0.088404
# [600]	valid_0's binary_logloss: 0.0884064
# [601]	valid_0's binary_logloss: 0.0883978
# [602]	valid_0's binary_logloss: 0.0883929
# [603]	valid_0's binary_logloss: 0.0883921
# [604]	valid_0's binary_logloss: 0.0883971
# [605]	valid_0's binary_logloss: 0.0883939
# [606]	valid_0's binary_logloss: 0.0883898
# [607]	valid_0's binary_logloss: 0.0883925
# [608]	valid_0's binary_logloss: 0.0883968
# [609]	valid_0's binary_logloss: 0.088397
# [610]	valid_0's binary_logloss: 0.0884025
# [611]	valid_0's binary_logloss: 0.0883992
# [612]	valid_0's binary_logloss: 0.0883956
# [613]	valid_0's binary_logloss: 0.0884046
# [614]	valid_0's binary_logloss: 0.0884016
# [615]	valid_0's binary_logloss: 0.0883933
# [616]	valid_0's binary_logloss: 0.0883951
# [617]	valid_0's binary_logloss: 0.0883993
# [618]	valid_0's binary_logloss: 0.0883945
# [619]	valid_0's binary_logloss: 0.088402
# [620]	valid_0's binary_logloss: 0.0884025
# [621]	valid_0's binary_logloss: 0.0884024
# [622]	valid_0's binary_logloss: 0.0883989
# [623]	valid_0's binary_logloss: 0.0883888
# [624]	valid_0's binary_logloss: 0.0883899
# [625]	valid_0's binary_logloss: 0.0883882
# [626]	valid_0's binary_logloss: 0.0883918
# [627]	valid_0's binary_logloss: 0.0883828
# [628]	valid_0's binary_logloss: 0.0883829
# [629]	valid_0's binary_logloss: 0.0883893
# [630]	valid_0's binary_logloss: 0.0883857
# [631]	valid_0's binary_logloss: 0.0883911
# [632]	valid_0's binary_logloss: 0.0883885
# [633]	valid_0's binary_logloss: 0.0883889
# [634]	valid_0's binary_logloss: 0.0883856
# [635]	valid_0's binary_logloss: 0.0883835
# [636]	valid_0's binary_logloss: 0.0883842
# [637]	valid_0's binary_logloss: 0.0883732
# [638]	valid_0's binary_logloss: 0.088377
# [639]	valid_0's binary_logloss: 0.0883755
# [640]	valid_0's binary_logloss: 0.088374
# [641]	valid_0's binary_logloss: 0.0883772
# [642]	valid_0's binary_logloss: 0.088377
# [643]	valid_0's binary_logloss: 0.0883719
# [644]	valid_0's binary_logloss: 0.0883753
# [645]	valid_0's binary_logloss: 0.0883729
# [646]	valid_0's binary_logloss: 0.0883657
# [647]	valid_0's binary_logloss: 0.0883671
# [648]	valid_0's binary_logloss: 0.088364
# [649]	valid_0's binary_logloss: 0.0883604
# [650]	valid_0's binary_logloss: 0.0883572
# [651]	valid_0's binary_logloss: 0.0883559
# [652]	valid_0's binary_logloss: 0.0883533
# [653]	valid_0's binary_logloss: 0.0883583
# [654]	valid_0's binary_logloss: 0.088359
# [655]	valid_0's binary_logloss: 0.0883642
# [656]	valid_0's binary_logloss: 0.0883578
# [657]	valid_0's binary_logloss: 0.0883461
# [658]	valid_0's binary_logloss: 0.0883459
# [659]	valid_0's binary_logloss: 0.088349
# [660]	valid_0's binary_logloss: 0.0883564
# [661]	valid_0's binary_logloss: 0.0883551
# [662]	valid_0's binary_logloss: 0.0883486
# [663]	valid_0's binary_logloss: 0.0883475
# [664]	valid_0's binary_logloss: 0.0883408
# [665]	valid_0's binary_logloss: 0.0883452
# [666]	valid_0's binary_logloss: 0.0883451
# [667]	valid_0's binary_logloss: 0.0883406
# [668]	valid_0's binary_logloss: 0.0883454
# [669]	valid_0's binary_logloss: 0.0883486
# [670]	valid_0's binary_logloss: 0.088348
# [671]	valid_0's binary_logloss: 0.0883517
# [672]	valid_0's binary_logloss: 0.0883472
# [673]	valid_0's binary_logloss: 0.0883451
# [674]	valid_0's binary_logloss: 0.0883433
# [675]	valid_0's binary_logloss: 0.0883515
# [676]	valid_0's binary_logloss: 0.0883461
# [677]	valid_0's binary_logloss: 0.0883422
# [678]	valid_0's binary_logloss: 0.0883414
# [679]	valid_0's binary_logloss: 0.0883449
# [680]	valid_0's binary_logloss: 0.0883357
# [681]	valid_0's binary_logloss: 0.0883346
# [682]	valid_0's binary_logloss: 0.0883297
# [683]	valid_0's binary_logloss: 0.0883222
# [684]	valid_0's binary_logloss: 0.0883268
# [685]	valid_0's binary_logloss: 0.0883281
# [686]	valid_0's binary_logloss: 0.0883244
# [687]	valid_0's binary_logloss: 0.0883197
# [688]	valid_0's binary_logloss: 0.0883182
# [689]	valid_0's binary_logloss: 0.088323
# [690]	valid_0's binary_logloss: 0.0883265
# [691]	valid_0's binary_logloss: 0.0883257
# [692]	valid_0's binary_logloss: 0.0883287
# [693]	valid_0's binary_logloss: 0.0883258
# [694]	valid_0's binary_logloss: 0.0883256
# [695]	valid_0's binary_logloss: 0.0883231
# [696]	valid_0's binary_logloss: 0.08833
# [697]	valid_0's binary_logloss: 0.0883308
# [698]	valid_0's binary_logloss: 0.0883344
# [699]	valid_0's binary_logloss: 0.088332
# [700]	valid_0's binary_logloss: 0.0883359
# [701]	valid_0's binary_logloss: 0.0883421
# [702]	valid_0's binary_logloss: 0.0883367
# [703]	valid_0's binary_logloss: 0.0883327
# [704]	valid_0's binary_logloss: 0.0883326
# [705]	valid_0's binary_logloss: 0.0883337
# [706]	valid_0's binary_logloss: 0.0883316
# [707]	valid_0's binary_logloss: 0.0883246
# [708]	valid_0's binary_logloss: 0.0883284
# [709]	valid_0's binary_logloss: 0.0883296
# [710]	valid_0's binary_logloss: 0.0883264
# [711]	valid_0's binary_logloss: 0.0883158
# [712]	valid_0's binary_logloss: 0.0883127
# [713]	valid_0's binary_logloss: 0.0883087
# [714]	valid_0's binary_logloss: 0.0883043
# [715]	valid_0's binary_logloss: 0.0883078
# [716]	valid_0's binary_logloss: 0.0883059
# [717]	valid_0's binary_logloss: 0.088311
# [718]	valid_0's binary_logloss: 0.0883168
# [719]	valid_0's binary_logloss: 0.0883117
# [720]	valid_0's binary_logloss: 0.088315
# [721]	valid_0's binary_logloss: 0.0883133
# [722]	valid_0's binary_logloss: 0.0883146
# [723]	valid_0's binary_logloss: 0.0883145
# [724]	valid_0's binary_logloss: 0.0883109
# [725]	valid_0's binary_logloss: 0.0883091
# [726]	valid_0's binary_logloss: 0.0883108
# [727]	valid_0's binary_logloss: 0.0883117
# [728]	valid_0's binary_logloss: 0.0883142
# [729]	valid_0's binary_logloss: 0.08832
# [730]	valid_0's binary_logloss: 0.0883179
# [731]	valid_0's binary_logloss: 0.0883139
# [732]	valid_0's binary_logloss: 0.0883106
# [733]	valid_0's binary_logloss: 0.0883094
# [734]	valid_0's binary_logloss: 0.0883113
# [735]	valid_0's binary_logloss: 0.0883132
# [736]	valid_0's binary_logloss: 0.0883147
# [737]	valid_0's binary_logloss: 0.0883126
# [738]	valid_0's binary_logloss: 0.0883173
# [739]	valid_0's binary_logloss: 0.0883255
# [740]	valid_0's binary_logloss: 0.0883249
# [741]	valid_0's binary_logloss: 0.0883203
# [742]	valid_0's binary_logloss: 0.0883205
# [743]	valid_0's binary_logloss: 0.0883282
# [744]	valid_0's binary_logloss: 0.0883257
# [745]	valid_0's binary_logloss: 0.0883248
# [746]	valid_0's binary_logloss: 0.08832
# [747]	valid_0's binary_logloss: 0.0883266
# [748]	valid_0's binary_logloss: 0.0883276
# [749]	valid_0's binary_logloss: 0.088326
# [750]	valid_0's binary_logloss: 0.0883224
# [751]	valid_0's binary_logloss: 0.0883192
# [752]	valid_0's binary_logloss: 0.088314
# [753]	valid_0's binary_logloss: 0.0883081
# [754]	valid_0's binary_logloss: 0.0882972
# [755]	valid_0's binary_logloss: 0.0882888
# [756]	valid_0's binary_logloss: 0.0882877
# [757]	valid_0's binary_logloss: 0.0882897
# [758]	valid_0's binary_logloss: 0.0882876
# [759]	valid_0's binary_logloss: 0.0882974
# [760]	valid_0's binary_logloss: 0.0883027
# [761]	valid_0's binary_logloss: 0.0883022
# [762]	valid_0's binary_logloss: 0.0883065
# [763]	valid_0's binary_logloss: 0.0883067
# [764]	valid_0's binary_logloss: 0.0883073
# [765]	valid_0's binary_logloss: 0.0883056
# [766]	valid_0's binary_logloss: 0.0882999
# [767]	valid_0's binary_logloss: 0.0882953
# [768]	valid_0's binary_logloss: 0.088294
# [769]	valid_0's binary_logloss: 0.0882939
# [770]	valid_0's binary_logloss: 0.0882912
# [771]	valid_0's binary_logloss: 0.0882989
# [772]	valid_0's binary_logloss: 0.0883047
# [773]	valid_0's binary_logloss: 0.0883034
# [774]	valid_0's binary_logloss: 0.0883107
# [775]	valid_0's binary_logloss: 0.0883068
# [776]	valid_0's binary_logloss: 0.0883099
# [777]	valid_0's binary_logloss: 0.0883171
# [778]	valid_0's binary_logloss: 0.0883152
# [779]	valid_0's binary_logloss: 0.0883142
# [780]	valid_0's binary_logloss: 0.0883188
# [781]	valid_0's binary_logloss: 0.0883191
# [782]	valid_0's binary_logloss: 0.0883242
# [783]	valid_0's binary_logloss: 0.088324
# [784]	valid_0's binary_logloss: 0.0883232
# [785]	valid_0's binary_logloss: 0.0883226
# [786]	valid_0's binary_logloss: 0.0883261
# [787]	valid_0's binary_logloss: 0.0883214
# [788]	valid_0's binary_logloss: 0.0883189
# [789]	valid_0's binary_logloss: 0.0883182
# [790]	valid_0's binary_logloss: 0.088317
# [791]	valid_0's binary_logloss: 0.0883162
# [792]	valid_0's binary_logloss: 0.0883158
# [793]	valid_0's binary_logloss: 0.0883215
# [794]	valid_0's binary_logloss: 0.0883174
# [795]	valid_0's binary_logloss: 0.0883181
# [796]	valid_0's binary_logloss: 0.0883147
# [797]	valid_0's binary_logloss: 0.0883207
# [798]	valid_0's binary_logloss: 0.088309
# [799]	valid_0's binary_logloss: 0.0883094
# [800]	valid_0's binary_logloss: 0.0883114
# [801]	valid_0's binary_logloss: 0.0883087
# [802]	valid_0's binary_logloss: 0.0883073
# [803]	valid_0's binary_logloss: 0.0883029
# [804]	valid_0's binary_logloss: 0.0883037
# [805]	valid_0's binary_logloss: 0.0883007
# [806]	valid_0's binary_logloss: 0.088312
# [807]	valid_0's binary_logloss: 0.0883131
# [808]	valid_0's binary_logloss: 0.0883101
# [809]	valid_0's binary_logloss: 0.0883059
# [810]	valid_0's binary_logloss: 0.088312
# [811]	valid_0's binary_logloss: 0.0883136
# [812]	valid_0's binary_logloss: 0.0883111
# [813]	valid_0's binary_logloss: 0.0883143
# [814]	valid_0's binary_logloss: 0.0883113
# [815]	valid_0's binary_logloss: 0.088319
# [816]	valid_0's binary_logloss: 0.088327
# [817]	valid_0's binary_logloss: 0.0883315
# [818]	valid_0's binary_logloss: 0.0883303
# [819]	valid_0's binary_logloss: 0.0883248
# [820]	valid_0's binary_logloss: 0.0883299
# [821]	valid_0's binary_logloss: 0.0883329
# [822]	valid_0's binary_logloss: 0.0883364
# [823]	valid_0's binary_logloss: 0.0883394
# [824]	valid_0's binary_logloss: 0.0883351
# [825]	valid_0's binary_logloss: 0.088337
# [826]	valid_0's binary_logloss: 0.0883369
# [827]	valid_0's binary_logloss: 0.0883364
# [828]	valid_0's binary_logloss: 0.0883332
# [829]	valid_0's binary_logloss: 0.0883292
# [830]	valid_0's binary_logloss: 0.0883246
# [831]	valid_0's binary_logloss: 0.088324
# [832]	valid_0's binary_logloss: 0.0883235
# [833]	valid_0's binary_logloss: 0.0883227
# [834]	valid_0's binary_logloss: 0.0883168
# [835]	valid_0's binary_logloss: 0.0883131
# [836]	valid_0's binary_logloss: 0.0883115
# [837]	valid_0's binary_logloss: 0.0883156
# [838]	valid_0's binary_logloss: 0.0883172
# [839]	valid_0's binary_logloss: 0.0883194
# [840]	valid_0's binary_logloss: 0.0883174
# [841]	valid_0's binary_logloss: 0.088318
# [842]	valid_0's binary_logloss: 0.0883193
# [843]	valid_0's binary_logloss: 0.0883228
# [844]	valid_0's binary_logloss: 0.0883132
# [845]	valid_0's binary_logloss: 0.0883045
# [846]	valid_0's binary_logloss: 0.0883019
# [847]	valid_0's binary_logloss: 0.0882999
# [848]	valid_0's binary_logloss: 0.0883021
# [849]	valid_0's binary_logloss: 0.088306
# [850]	valid_0's binary_logloss: 0.0883085
# [851]	valid_0's binary_logloss: 0.0883069
# [852]	valid_0's binary_logloss: 0.0883038
# [853]	valid_0's binary_logloss: 0.0882985
# [854]	valid_0's binary_logloss: 0.0882959
# [855]	valid_0's binary_logloss: 0.0882887
# [856]	valid_0's binary_logloss: 0.0882842
# [857]	valid_0's binary_logloss: 0.088289
# [858]	valid_0's binary_logloss: 0.0882904
# [859]	valid_0's binary_logloss: 0.0882906
# [860]	valid_0's binary_logloss: 0.0882892
# [861]	valid_0's binary_logloss: 0.0882895
# [862]	valid_0's binary_logloss: 0.0882947
# [863]	valid_0's binary_logloss: 0.0883016
# [864]	valid_0's binary_logloss: 0.0883039
# [865]	valid_0's binary_logloss: 0.0882987
# [866]	valid_0's binary_logloss: 0.0882958
# [867]	valid_0's binary_logloss: 0.0882912
# [868]	valid_0's binary_logloss: 0.0882898
# [869]	valid_0's binary_logloss: 0.0882835
# [870]	valid_0's binary_logloss: 0.0882858
# [871]	valid_0's binary_logloss: 0.0882853
# [872]	valid_0's binary_logloss: 0.0882775
# [873]	valid_0's binary_logloss: 0.0882693
# [874]	valid_0's binary_logloss: 0.0882702
# [875]	valid_0's binary_logloss: 0.0882608
# [876]	valid_0's binary_logloss: 0.0882577
# [877]	valid_0's binary_logloss: 0.0882602
# [878]	valid_0's binary_logloss: 0.0882555
# [879]	valid_0's binary_logloss: 0.0882537
# [880]	valid_0's binary_logloss: 0.0882506
# [881]	valid_0's binary_logloss: 0.0882492
# [882]	valid_0's binary_logloss: 0.0882452
# [883]	valid_0's binary_logloss: 0.0882431
# [884]	valid_0's binary_logloss: 0.0882464
# [885]	valid_0's binary_logloss: 0.0882489
# [886]	valid_0's binary_logloss: 0.0882498
# [887]	valid_0's binary_logloss: 0.0882515
# [888]	valid_0's binary_logloss: 0.0882437
# [889]	valid_0's binary_logloss: 0.0882438
# [890]	valid_0's binary_logloss: 0.0882447
# [891]	valid_0's binary_logloss: 0.0882399
# [892]	valid_0's binary_logloss: 0.0882406
# [893]	valid_0's binary_logloss: 0.0882392
# [894]	valid_0's binary_logloss: 0.0882448
# [895]	valid_0's binary_logloss: 0.0882486
# [896]	valid_0's binary_logloss: 0.0882487
# [897]	valid_0's binary_logloss: 0.0882479
# [898]	valid_0's binary_logloss: 0.0882435
# [899]	valid_0's binary_logloss: 0.0882447
# [900]	valid_0's binary_logloss: 0.0882441
# [901]	valid_0's binary_logloss: 0.088237
# [902]	valid_0's binary_logloss: 0.0882373
# [903]	valid_0's binary_logloss: 0.0882335
# [904]	valid_0's binary_logloss: 0.0882315
# [905]	valid_0's binary_logloss: 0.088235
# [906]	valid_0's binary_logloss: 0.0882341
# [907]	valid_0's binary_logloss: 0.0882311
# [908]	valid_0's binary_logloss: 0.0882245
# [909]	valid_0's binary_logloss: 0.0882279
# [910]	valid_0's binary_logloss: 0.0882208
# [911]	valid_0's binary_logloss: 0.0882267
# [912]	valid_0's binary_logloss: 0.0882256
# [913]	valid_0's binary_logloss: 0.088229
# [914]	valid_0's binary_logloss: 0.088231
# [915]	valid_0's binary_logloss: 0.0882326
# [916]	valid_0's binary_logloss: 0.0882272
# [917]	valid_0's binary_logloss: 0.0882276
# [918]	valid_0's binary_logloss: 0.0882305
# [919]	valid_0's binary_logloss: 0.0882255
# [920]	valid_0's binary_logloss: 0.0882265
# [921]	valid_0's binary_logloss: 0.0882254
# [922]	valid_0's binary_logloss: 0.0882345
# [923]	valid_0's binary_logloss: 0.0882391
# [924]	valid_0's binary_logloss: 0.0882373
# [925]	valid_0's binary_logloss: 0.0882338
# [926]	valid_0's binary_logloss: 0.0882385
# [927]	valid_0's binary_logloss: 0.0882407
# [928]	valid_0's binary_logloss: 0.0882356
# [929]	valid_0's binary_logloss: 0.0882356
# [930]	valid_0's binary_logloss: 0.0882377
# [931]	valid_0's binary_logloss: 0.0882315
# [932]	valid_0's binary_logloss: 0.0882277
# [933]	valid_0's binary_logloss: 0.0882323
# [934]	valid_0's binary_logloss: 0.088228
# [935]	valid_0's binary_logloss: 0.0882251
# [936]	valid_0's binary_logloss: 0.0882329
# [937]	valid_0's binary_logloss: 0.0882296
# [938]	valid_0's binary_logloss: 0.0882343
# [939]	valid_0's binary_logloss: 0.0882325
# [940]	valid_0's binary_logloss: 0.0882296
# [941]	valid_0's binary_logloss: 0.0882269
# [942]	valid_0's binary_logloss: 0.08823
# [943]	valid_0's binary_logloss: 0.0882308
# [944]	valid_0's binary_logloss: 0.0882202
# [945]	valid_0's binary_logloss: 0.0882189
# [946]	valid_0's binary_logloss: 0.0882165
# [947]	valid_0's binary_logloss: 0.0882072
# [948]	valid_0's binary_logloss: 0.0882144
# [949]	valid_0's binary_logloss: 0.0882143
# [950]	valid_0's binary_logloss: 0.0882152
# [951]	valid_0's binary_logloss: 0.0882179
# [952]	valid_0's binary_logloss: 0.0882141
# [953]	valid_0's binary_logloss: 0.0882161
# [954]	valid_0's binary_logloss: 0.0882123
# [955]	valid_0's binary_logloss: 0.0882187
# [956]	valid_0's binary_logloss: 0.0882194
# [957]	valid_0's binary_logloss: 0.0882153
# [958]	valid_0's binary_logloss: 0.0882161
# [959]	valid_0's binary_logloss: 0.0882151
# [960]	valid_0's binary_logloss: 0.0882169
# [961]	valid_0's binary_logloss: 0.0882165
# [962]	valid_0's binary_logloss: 0.0882176
# [963]	valid_0's binary_logloss: 0.0882094
# [964]	valid_0's binary_logloss: 0.0882103
# [965]	valid_0's binary_logloss: 0.0882079
# [966]	valid_0's binary_logloss: 0.0882123
# [967]	valid_0's binary_logloss: 0.0882121
# [968]	valid_0's binary_logloss: 0.0882129
# [969]	valid_0's binary_logloss: 0.0882237
# [970]	valid_0's binary_logloss: 0.0882303
# [971]	valid_0's binary_logloss: 0.088227
# [972]	valid_0's binary_logloss: 0.088227
# [973]	valid_0's binary_logloss: 0.0882395
# [974]	valid_0's binary_logloss: 0.0882397
# [975]	valid_0's binary_logloss: 0.0882416
# [976]	valid_0's binary_logloss: 0.088243
# [977]	valid_0's binary_logloss: 0.0882362
# [978]	valid_0's binary_logloss: 0.0882408
# [979]	valid_0's binary_logloss: 0.0882449
# [980]	valid_0's binary_logloss: 0.0882411
# [981]	valid_0's binary_logloss: 0.0882401
# [982]	valid_0's binary_logloss: 0.0882357
# [983]	valid_0's binary_logloss: 0.0882401
# [984]	valid_0's binary_logloss: 0.088242
# [985]	valid_0's binary_logloss: 0.0882348
# [986]	valid_0's binary_logloss: 0.0882398
# [987]	valid_0's binary_logloss: 0.0882334
# [988]	valid_0's binary_logloss: 0.0882336
# [989]	valid_0's binary_logloss: 0.0882348
# [990]	valid_0's binary_logloss: 0.0882301
# [991]	valid_0's binary_logloss: 0.0882211
# [992]	valid_0's binary_logloss: 0.088223
# [993]	valid_0's binary_logloss: 0.0882221
# [994]	valid_0's binary_logloss: 0.0882177
# [995]	valid_0's binary_logloss: 0.0882154
# [996]	valid_0's binary_logloss: 0.0882158
# [997]	valid_0's binary_logloss: 0.0882141
# [998]	valid_0's binary_logloss: 0.0882138
# [999]	valid_0's binary_logloss: 0.0882238
# [1000]	valid_0's binary_logloss: 0.0882237
# [1001]	valid_0's binary_logloss: 0.0882222
# [1002]	valid_0's binary_logloss: 0.0882261
# [1003]	valid_0's binary_logloss: 0.0882215
# [1004]	valid_0's binary_logloss: 0.0882226
# [1005]	valid_0's binary_logloss: 0.0882238
# [1006]	valid_0's binary_logloss: 0.0882258
# [1007]	valid_0's binary_logloss: 0.0882252
# [1008]	valid_0's binary_logloss: 0.0882166
# [1009]	valid_0's binary_logloss: 0.0882229
# [1010]	valid_0's binary_logloss: 0.0882215
# [1011]	valid_0's binary_logloss: 0.0882216
# [1012]	valid_0's binary_logloss: 0.0882207
# [1013]	valid_0's binary_logloss: 0.0882352
# [1014]	valid_0's binary_logloss: 0.0882357
# [1015]	valid_0's binary_logloss: 0.0882329
# [1016]	valid_0's binary_logloss: 0.0882267
# [1017]	valid_0's binary_logloss: 0.0882297
# [1018]	valid_0's binary_logloss: 0.0882311
# [1019]	valid_0's binary_logloss: 0.0882318
# [1020]	valid_0's binary_logloss: 0.088237
# [1021]	valid_0's binary_logloss: 0.088234
# [1022]	valid_0's binary_logloss: 0.088237
# [1023]	valid_0's binary_logloss: 0.0882367
# [1024]	valid_0's binary_logloss: 0.0882344
# [1025]	valid_0's binary_logloss: 0.0882341
# [1026]	valid_0's binary_logloss: 0.0882388
# [1027]	valid_0's binary_logloss: 0.0882336
# [1028]	valid_0's binary_logloss: 0.0882358
# [1029]	valid_0's binary_logloss: 0.0882349
# [1030]	valid_0's binary_logloss: 0.0882336
# [1031]	valid_0's binary_logloss: 0.0882391
# [1032]	valid_0's binary_logloss: 0.088239
# [1033]	valid_0's binary_logloss: 0.0882385
# [1034]	valid_0's binary_logloss: 0.0882396
# [1035]	valid_0's binary_logloss: 0.0882358
# [1036]	valid_0's binary_logloss: 0.0882364
# [1037]	valid_0's binary_logloss: 0.0882365
# [1038]	valid_0's binary_logloss: 0.0882392
# [1039]	valid_0's binary_logloss: 0.0882343
# [1040]	valid_0's binary_logloss: 0.0882323
# [1041]	valid_0's binary_logloss: 0.0882337
# [1042]	valid_0's binary_logloss: 0.0882351
# [1043]	valid_0's binary_logloss: 0.0882377
# [1044]	valid_0's binary_logloss: 0.0882396
# [1045]	valid_0's binary_logloss: 0.0882349
# [1046]	valid_0's binary_logloss: 0.0882349
# [1047]	valid_0's binary_logloss: 0.088235
# [1048]	valid_0's binary_logloss: 0.0882381
# [1049]	valid_0's binary_logloss: 0.0882377
# [1050]	valid_0's binary_logloss: 0.0882338
# [1051]	valid_0's binary_logloss: 0.0882361
# [1052]	valid_0's binary_logloss: 0.0882375
# [1053]	valid_0's binary_logloss: 0.0882397
# [1054]	valid_0's binary_logloss: 0.0882458
# [1055]	valid_0's binary_logloss: 0.0882405
# [1056]	valid_0's binary_logloss: 0.0882401
# [1057]	valid_0's binary_logloss: 0.0882431
# [1058]	valid_0's binary_logloss: 0.0882432
# [1059]	valid_0's binary_logloss: 0.0882377
# [1060]	valid_0's binary_logloss: 0.0882375
# [1061]	valid_0's binary_logloss: 0.0882377
# [1062]	valid_0's binary_logloss: 0.0882364
# [1063]	valid_0's binary_logloss: 0.0882342
# [1064]	valid_0's binary_logloss: 0.0882321
# [1065]	valid_0's binary_logloss: 0.0882286
# [1066]	valid_0's binary_logloss: 0.0882252
# [1067]	valid_0's binary_logloss: 0.0882274
# [1068]	valid_0's binary_logloss: 0.0882287
# [1069]	valid_0's binary_logloss: 0.0882313
# [1070]	valid_0's binary_logloss: 0.0882342
# [1071]	valid_0's binary_logloss: 0.0882378
# [1072]	valid_0's binary_logloss: 0.0882368
# [1073]	valid_0's binary_logloss: 0.0882351
# [1074]	valid_0's binary_logloss: 0.0882337
# [1075]	valid_0's binary_logloss: 0.0882364
# [1076]	valid_0's binary_logloss: 0.0882405
# [1077]	valid_0's binary_logloss: 0.0882385
# [1078]	valid_0's binary_logloss: 0.0882413
# [1079]	valid_0's binary_logloss: 0.0882389
# [1080]	valid_0's binary_logloss: 0.0882393
# [1081]	valid_0's binary_logloss: 0.0882335
# [1082]	valid_0's binary_logloss: 0.0882396
# [1083]	valid_0's binary_logloss: 0.0882344
# [1084]	valid_0's binary_logloss: 0.0882311
# [1085]	valid_0's binary_logloss: 0.0882297
# [1086]	valid_0's binary_logloss: 0.0882331
# [1087]	valid_0's binary_logloss: 0.0882294
# [1088]	valid_0's binary_logloss: 0.0882267
# [1089]	valid_0's binary_logloss: 0.0882293
# [1090]	valid_0's binary_logloss: 0.0882308
# [1091]	valid_0's binary_logloss: 0.0882293
# [1092]	valid_0's binary_logloss: 0.0882353
# [1093]	valid_0's binary_logloss: 0.0882349
# [1094]	valid_0's binary_logloss: 0.0882287
# [1095]	valid_0's binary_logloss: 0.0882348
# [1096]	valid_0's binary_logloss: 0.0882314
# [1097]	valid_0's binary_logloss: 0.0882334
# [1098]	valid_0's binary_logloss: 0.0882471
# [1099]	valid_0's binary_logloss: 0.0882482
# [1100]	valid_0's binary_logloss: 0.088251
# [1101]	valid_0's binary_logloss: 0.0882525
# [1102]	valid_0's binary_logloss: 0.0882482
# [1103]	valid_0's binary_logloss: 0.0882432
# [1104]	valid_0's binary_logloss: 0.0882445
# [1105]	valid_0's binary_logloss: 0.088247
# [1106]	valid_0's binary_logloss: 0.0882451
# [1107]	valid_0's binary_logloss: 0.088241
# [1108]	valid_0's binary_logloss: 0.0882354
# [1109]	valid_0's binary_logloss: 0.0882343
# [1110]	valid_0's binary_logloss: 0.0882306
# [1111]	valid_0's binary_logloss: 0.0882279
# [1112]	valid_0's binary_logloss: 0.0882339
# [1113]	valid_0's binary_logloss: 0.0882425
# [1114]	valid_0's binary_logloss: 0.0882472
# [1115]	valid_0's binary_logloss: 0.0882467
# [1116]	valid_0's binary_logloss: 0.088246
# [1117]	valid_0's binary_logloss: 0.0882478
# [1118]	valid_0's binary_logloss: 0.0882489
# [1119]	valid_0's binary_logloss: 0.0882449
# [1120]	valid_0's binary_logloss: 0.088236
# [1121]	valid_0's binary_logloss: 0.0882344
# [1122]	valid_0's binary_logloss: 0.0882373
# [1123]	valid_0's binary_logloss: 0.0882313
# [1124]	valid_0's binary_logloss: 0.0882358
# [1125]	valid_0's binary_logloss: 0.0882325
# [1126]	valid_0's binary_logloss: 0.0882383
# [1127]	valid_0's binary_logloss: 0.0882431
# [1128]	valid_0's binary_logloss: 0.0882345
# [1129]	valid_0's binary_logloss: 0.0882349
# [1130]	valid_0's binary_logloss: 0.0882379
# [1131]	valid_0's binary_logloss: 0.088238
# [1132]	valid_0's binary_logloss: 0.0882386
# [1133]	valid_0's binary_logloss: 0.0882389
# [1134]	valid_0's binary_logloss: 0.0882396
# [1135]	valid_0's binary_logloss: 0.0882385
# [1136]	valid_0's binary_logloss: 0.0882335
# [1137]	valid_0's binary_logloss: 0.0882353
# [1138]	valid_0's binary_logloss: 0.0882282
# [1139]	valid_0's binary_logloss: 0.08823
# [1140]	valid_0's binary_logloss: 0.0882319
# [1141]	valid_0's binary_logloss: 0.0882327
# [1142]	valid_0's binary_logloss: 0.0882263
# [1143]	valid_0's binary_logloss: 0.0882239
# [1144]	valid_0's binary_logloss: 0.088224
# [1145]	valid_0's binary_logloss: 0.0882266
# [1146]	valid_0's binary_logloss: 0.0882255
# [1147]	valid_0's binary_logloss: 0.0882212
# Early stopping, best iteration is:
# [947]	valid_0's binary_logloss: 0.0882072
# context_id                   5913
# shop_score_delivery          2220
# context_page_id              2132
# shop_score_description       2106
# shop_score_service           2085
# shop_review_positive_rate    1369
# item_sales_level             1315
# avg_collected_brand          1282
# hour                         1134
# instance_nums_shop           1123
# item_collected_level         1057
# item_pv_level                 951
# instance_nums_brand           698
# item_per_shop                 689
# category_1                    673
# shop_review_num_level         658
# item_price_level              567
# item_nums_brand               566
# item_nums_shop                547
# item_brand                    536
# shop_star_level               518
# user_age_level3               514
# fans_nums_shop                469
# user_age_level2               368
# fans_nums_brand               344
# user_gender_id3               326
# user_gender_id2               291
# shop_nums_brand               291
# user_star_level1              209
# user_nums_shop                207
# brand_nums_shop               191
# user_nums_brand               143
# user_star_level2              116
# user_age_level1                96
# user_gender_id1                91
# brand_label7                   85
# user_star_level3               59
# shop_label1                    53
# brand_label5                   43
# user_occupation_id1            36
# brand_label3                   34
# category_2                     28
# shop_label2                    23
# user_occupation_id2            17
# brand_label1                   13
# brand_label6                    8
# shop_label3                     3
# brand_label4                    1
# brand_label2                    0
# dtype: int32
# (49,)
# 误差  -0.0882071928721
# KS  0.243872862161
# C:\Users\Leo Mao\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\Leo Mao\Anaconda3\lib\site-packages\ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print('KS ', ks_metric(test['is_trade'], test['pred']))
# Out:
# KS  0.000620017714792

# %%
col
# Out:
# ['item_price_level',
#  'item_sales_level',
#  'item_collected_level',
#  'item_pv_level',
#  'context_id',
#  'context_page_id',
#  'shop_review_num_level',
#  'shop_review_positive_rate',
#  'shop_star_level',
#  'shop_score_service',
#  'shop_score_delivery',
#  'shop_score_description',
#  'hour',
#  'category_1',
#  'category_2',
#  'user_gender_id1',
#  'user_gender_id2',
#  'user_gender_id3',
#  'user_age_level1',
#  'user_age_level2',
#  'user_age_level3',
#  'user_occupation_id1',
#  'user_occupation_id2',
#  'user_star_level1',
#  'user_star_level2',
#  'user_star_level3',
#  'item_nums_brand',
#  'shop_nums_brand',
#  'instance_nums_brand',
#  'user_nums_brand',
#  'fans_nums_brand',
#  'avg_collected_brand',
#  'item_per_shop',
#  'brand_label1',
#  'brand_label2',
#  'brand_label3',
#  'brand_label4',
#  'brand_label5',
#  'brand_label6',
#  'brand_label7',
#  'item_nums_shop',
#  'brand_nums_shop',
#  'instance_nums_shop',
#  'user_nums_shop',
#  'fans_nums_shop',
#  'item_brand',
#  'shop_label1',
#  'shop_label2',
#  'shop_label3']
